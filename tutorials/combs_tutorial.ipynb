# %% [markdown]
# ## COMBS Tutorial
# ### Import COMBS and related packages

# %%
import combs2
import prody as pr
import pandas as pd
import pickle
pd.set_option("display.max_columns", None)

# %% [markdown]
# ### Setup template PDBs as ProDy AtomGroup objects

# %%
input_dir = '/Users/npolizzi/Projects/design/Combs2/tutorials/files/jupyter_notebook/'

# %%
gly_pdb_name = '00009.f63440efff7e.allbb_ala_min_gly_0001.pdb'
ala_pdb_name = '00009.f63440efff7e.allbb_ala_min_ala_0001.pdb'
pdb_gly_path = input_dir + gly_pdb_name
pdb_ala_path = input_dir + ala_pdb_name

pdb_gly = pr.parsePDB(pdb_gly_path)
pdb_ala = pr.parsePDB(pdb_ala_path)
# Out:
# @> 1039 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> 1483 atoms and 1 coordinate set(s) were parsed in 0.02s.

# %% [markdown]
# ### Use ProDy PDB objects to setup a COMBS template

# %%
template = combs2.design.template.Template(pdb_gly)

# %% [markdown]
# Define the surface of the protein via its alpha hull, here with radius = 9 Ang.

# %%
template.set_alpha_hull(pdb_ala, alpha=9)

# %% [markdown]
# ### Write a residue file for design with COMBS.

# %%
resnums = [21, 28, 44, 48, 51, 55, 95, 99, 102]
chains = ['A'] * len(resnums)
segs = ['A'] * len(resnums)
segs_chains_resnums = zip(segs, chains, resnums)

outpath_resfile = input_dir

combs2.design.functions.write_resfile(template,
                                      CGs=['bb_cco', 'conh2'],
                                      outpath=outpath_resfile,
                                      filename='resfile',
                                      tag='',
                                      resindices=None,
                                      segs_chains_resnums=segs_chains_resnums,
                                      pikaa_dict=None,
                                      bb_dep=1,
                                      use_enriched_vdMs=True,
                                      CA_burial_distance=None,
                                      exclude_exposed=False,
                                      exclude_intermed=False,
                                      exclude_buried=False,
                                      top_exposed=2,
                                      top_intermed=None,
                                      top_buried=None,
                                      alpha_hull_radius=9,
                                      use_propensities=True,
                                      propensity_threshold=0.9,
                                      use_abple=True,
                                      use_dssp=False,
                                      path_to_pdb_for_dssp=None,
                                      allowed_exposed='KRDENQSTMAGP',
                                      allowed_intermed='NQSTCMAGPVIL',
                                      allowed_buried='AGSTMCPVILHFWY',
                                      hb_only_residues='',
                                      all_contact_residues='GHFWY')

# %% [markdown]
# Peak into the resfile:

# %%
with open(input_dir + 'resfile.txt', 'r') as infile:
    for _ in range(15):
        print(infile.readline().strip())
# Out:
# 48 A A, PIKAA PQRNTM, CG bb_cco, bbdep 1, top 2, enriched, hbond_only
# 48 A A, PIKAA G, CG bb_cco, bbdep 1, top 2, enriched
# 48 A A, PIKAA PSDQRNTM, CG conh2, bbdep 1, top 2, enriched, hbond_only
# 55 A A, PIKAA PQRNTM, CG bb_cco, bbdep 1, top 2, enriched, hbond_only
# 55 A A, PIKAA G, CG bb_cco, bbdep 1, top 2, enriched
# 55 A A, PIKAA PSDQRNTM, CG conh2, bbdep 1, top 2, enriched, hbond_only
# 99 A A, PIKAA PQRNTM, CG bb_cco, bbdep 1, top 2, enriched, hbond_only
# 99 A A, PIKAA G, CG bb_cco, bbdep 1, top 2, enriched
# 99 A A, PIKAA PSDQRNTM, CG conh2, bbdep 1, top 2, enriched, hbond_only
# 21 A A, PIKAA PVLCTIM, CG bb_cco, bbdep 1, enriched, hbond_only
# 21 A A, PIKAA FWHGY, CG bb_cco, bbdep 1, enriched
# 21 A A, PIKAA TMPS, CG conh2, bbdep 1, enriched, hbond_only
# 21 A A, PIKAA WHYF, CG conh2, bbdep 1, enriched
# 28 A A, PIKAA PVLCTIM, CG bb_cco, bbdep 1, enriched, hbond_only
# 28 A A, PIKAA FWHGY, CG bb_cco, bbdep 1, enriched

# %% [markdown]
# ### Make a COMBS Sample object to sample van der Mers (vdMs).

# %%
#path to COMBS residue file for design
path_to_resfile= input_dir + 'resfile.txt'

# path to vdM databases
path_to_database='/Volumes/disk1/Combs2/database/20211005/vdMs/'

s = combs2.design._sample.Sample(**dict(path_to_resfile=path_to_resfile,
                                        path_to_database=path_to_database))

# Read the resfile into the Sample object
s.read_resfile()

# %% [markdown]
# ### An aside about vdM databases...
# The vdM databases are Pandas dataframes; they contain a lot of information.  Below, the first 50 rows of the dataframe show two "instances" of SER / CONH2 vdMs.  Each vdM has a unique identifier comprised of 3 keys: *CG*, *rota*, and *probe_name*.  The chemical group (CG) of the vdM is always **Y** in column *chain* with *resnum*=10, and the contacting amino-acid is **X** in *chain* with *resnum*=10.  The dataframes also contain the backbone coordinates and other info for the flanking residues (i+-1) of chain X (resnums 9 and 11, respectively).

# %%
df = pd.read_parquet(path_to_database + 'conh2/SER.parquet.gzip')
df.head(50)
# Out:
#     resnum chain resname  name       beta  occ       c_x       c_y  \
# 0       10     Y     GLN    CG  30.020000  1.0 -0.751365 -1.069795
# 1       10     Y     GLN    CD  31.900000  1.0 -2.235665 -1.212207
# 2       10     Y     GLN   OE1  36.459999  1.0 -3.032754 -1.324243
# 3       10     Y     GLN   NE2  31.540001  1.0 -2.612607 -1.229967
# 4       10     Y     GLN  HE21  31.540001  1.0 -2.026131 -1.149159
# 5       10     Y     GLN  HE22  31.540001  1.0 -3.444020 -1.322592
# 6       10     X     SER     N  23.190001  1.0  1.450075 -0.014725
# 7       10     X     SER    CA  23.510000  1.0 -0.007380  0.012174
# 8       10     X     SER     C  23.690001  1.0 -0.535188 -1.417178
# 9       10     X     SER     O  26.389999  1.0 -1.324393 -1.807113
# 10      10     X     SER    CB  21.620001  1.0 -0.514173  0.777334
# 11      10     X     SER    OG  29.830000  1.0  0.215884  0.400733
# 12      10     X     SER     H  23.190001  1.0  1.804813  0.011314
# 13      10     X     SER    HA  23.510000  1.0 -0.327618  0.465845
# 14      10     X     SER   HB2  21.620001  1.0 -1.458483  0.597204
# 15      10     X     SER   HB3  21.620001  1.0 -0.425571  1.732080
# 16      10     X     SER    HG  29.830000  1.0  0.226206  1.038832
# 17       9     X     GLY     N  19.980000  1.0  4.083414  0.105290
# 18       9     X     GLY    CA  18.799999  1.0  3.659305 -0.109735
# 19       9     X     GLY     C  23.280001  1.0  2.149055 -0.074261
# 20       9     X     GLY     O  23.320000  1.0  1.619456 -0.074493
# 21      11     X     GLN     N  24.219999  1.0 -0.056653 -2.194905
# 22      11     X     GLN    CA  25.430000  1.0 -0.426721 -3.591948
# 23      11     X     GLN     C  30.200001  1.0 -0.151901 -3.881303
# 24      11     X     GLN     O  33.439999  1.0  0.288893 -2.995609
# 25      10     Y     ASN    CB  17.070000  1.0 -2.263700  4.370325
# 26      10     Y     ASN    CG  22.889999  1.0 -1.274804  5.015656
# 27      10     Y     ASN   OD1  29.180000  1.0 -0.313719  4.379061
# 28      10     Y     ASN   ND2  18.299999  1.0 -1.492157  6.282831
# 29      10     Y     ASN  HD21  18.299999  1.0 -0.951531  6.695799
# 30      10     Y     ASN  HD22  18.299999  1.0 -2.174720  6.694624
# 31      10     X     SER     N   9.960000  1.0  1.433240 -0.045104
# 32      10     X     SER    CA  11.360000  1.0 -0.025681  0.032453
# 33      10     X     SER     C  11.480000  1.0 -0.500051 -1.407079
# 34      10     X     SER     O  10.270000  1.0  0.139522 -2.276296
# 35      10     X     SER    CB  12.730000  1.0 -0.569424  0.787998
# 36      10     X     SER    OG  17.920000  1.0 -0.058694  0.267166
# 37      10     X     SER     H   9.960000  1.0  1.760368 -0.591761
# 38      10     X     SER    HA  11.360000  1.0 -0.346087  0.527268
# 39      10     X     SER   HB2  12.730000  1.0 -1.538212  0.734667
# 40      10     X     SER   HB3  12.730000  1.0 -0.337208  1.727475
# 41      10     X     SER    HG  17.920000  1.0 -0.695096  0.086096
# 42       9     X     TRP     N   5.530000  1.0  4.379028  1.725488
# 43       9     X     TRP    CA   7.300000  1.0  3.670161  0.464318
# 44       9     X     TRP     C   9.890000  1.0  2.168448  0.679272
# 45       9     X     TRP     O  13.510000  1.0  1.687867  1.523539
# 46      11     X     PHE     N   9.670000  1.0 -1.619996 -1.655981
# 47      11     X     PHE    CA  11.260000  1.0 -2.166576 -2.998079
# 48      11     X     PHE     C  13.440000  1.0 -3.677174 -2.908392
# 49      11     X     PHE     O  12.000000  1.0 -4.255901 -1.926477
#
#              c_z     c_D_x     c_D_y         c_D_z    c_H1_x    c_H1_y  \
# 0  -5.110119e+00       NaN       NaN           NaN       NaN       NaN
# 1  -4.846700e+00       NaN       NaN           NaN       NaN       NaN
# 2  -5.778465e+00       NaN       NaN           NaN       NaN       NaN
# 3  -3.578289e+00 -2.612607 -1.229967 -3.578289e+00 -2.026131 -1.149159
# 4  -2.953902e+00 -2.612607 -1.229967 -3.578289e+00 -2.026131 -1.149159
# 5  -3.377703e+00 -2.612607 -1.229967 -3.578289e+00 -3.444020 -1.322592
# 6  -1.143682e-15  1.450075 -0.014725 -1.143682e-15  1.804813  0.011314
# 7  -1.771283e-15       NaN       NaN           NaN       NaN       NaN
# 8  -1.574665e-15       NaN       NaN           NaN       NaN       NaN
# 9  -8.640326e-01       NaN       NaN           NaN       NaN       NaN
# 10 -1.220783e+00       NaN       NaN           NaN       NaN       NaN
# 11 -2.376462e+00  0.215884  0.400733 -2.376462e+00  0.226206  1.038832
# 12 -7.825614e-01  1.450075 -0.014725 -1.143682e-15  1.804813  0.011314
# 13  7.951392e-01       NaN       NaN           NaN       NaN       NaN
# 14 -1.354148e+00       NaN       NaN           NaN       NaN       NaN
# 15 -1.071496e+00       NaN       NaN           NaN       NaN       NaN
# 16 -2.922579e+00  0.215884  0.400733 -2.376462e+00  0.226206  1.038832
# 17 -3.697605e-01       NaN       NaN           NaN       NaN       NaN
# 18  9.982076e-01       NaN       NaN           NaN       NaN       NaN
# 19  1.128869e+00       NaN       NaN           NaN       NaN       NaN
# 20  2.233743e+00       NaN       NaN           NaN       NaN       NaN
# 21  9.631394e-01       NaN       NaN           NaN       NaN       NaN
# 22  1.138564e+00       NaN       NaN           NaN       NaN       NaN
# 23  2.602204e+00       NaN       NaN           NaN       NaN       NaN
# 24  3.323419e+00       NaN       NaN           NaN       NaN       NaN
# 25  6.617194e-01       NaN       NaN           NaN       NaN       NaN
# 26 -2.705066e-01       NaN       NaN           NaN       NaN       NaN
# 27 -7.066357e-01       NaN       NaN           NaN       NaN       NaN
# 28 -5.811689e-01 -1.492157  6.282831 -5.811689e-01 -0.951531  6.695799
# 29 -1.106899e+00 -1.492157  6.282831 -5.811689e-01 -0.951531  6.695799
# 30 -2.563632e-01 -1.492157  6.282831 -5.811689e-01 -2.174720  6.694624
# 31 -1.743305e-16  1.433240 -0.045104 -1.743305e-16  1.760368 -0.591761
# 32  5.465681e-17       NaN       NaN           NaN       NaN       NaN
# 33  1.266126e-16       NaN       NaN           NaN       NaN       NaN
# 34 -6.073644e-01       NaN       NaN           NaN       NaN       NaN
# 35 -1.217777e+00       NaN       NaN           NaN       NaN       NaN
# 36 -2.431304e+00 -0.058694  0.267166 -2.431304e+00 -0.695096  0.086096
# 37 -5.776771e-01  1.433240 -0.045104 -1.743305e-16  1.760368 -0.591761
# 38  7.706372e-01       NaN       NaN           NaN       NaN       NaN
# 39 -1.224956e+00       NaN       NaN           NaN       NaN       NaN
# 40 -1.145878e+00       NaN       NaN           NaN       NaN       NaN
# 41 -2.947965e+00 -0.058694  0.267166 -2.431304e+00 -0.695096  0.086096
# 42  6.888688e-01       NaN       NaN           NaN       NaN       NaN
# 43  7.843266e-01       NaN       NaN           NaN       NaN       NaN
# 44  8.327258e-01       NaN       NaN           NaN       NaN       NaN
# 45  1.582630e+00       NaN       NaN           NaN       NaN       NaN
# 46  6.666080e-01       NaN       NaN           NaN       NaN       NaN
# 47  7.765728e-01       NaN       NaN           NaN       NaN       NaN
# 48  7.583523e-01       NaN       NaN           NaN       NaN       NaN
# 49  1.233471e+00       NaN       NaN           NaN       NaN       NaN
#
#       c_H1_z   c_H2_x    c_H2_y    c_H2_z  c_H3_x  c_H3_y  c_H3_z  c_H4_x  \
# 0        NaN      NaN       NaN       NaN     NaN     NaN     NaN     NaN
# 1        NaN      NaN       NaN       NaN     NaN     NaN     NaN     NaN
# 2        NaN      NaN       NaN       NaN     NaN     NaN     NaN     NaN
# 3  -2.953902 -3.44402 -1.322592 -3.377703     NaN     NaN     NaN     NaN
# 4  -2.953902      NaN       NaN       NaN     NaN     NaN     NaN     NaN
# 5  -3.377703      NaN       NaN       NaN     NaN     NaN     NaN     NaN
# 6  -0.782561      NaN       NaN       NaN     NaN     NaN     NaN     NaN
# 7        NaN      NaN       NaN       NaN     NaN     NaN     NaN     NaN
# 8        NaN      NaN       NaN       NaN     NaN     NaN     NaN     NaN
# 9        NaN      NaN       NaN       NaN     NaN     NaN     NaN     NaN
# 10       NaN      NaN       NaN       NaN     NaN     NaN     NaN     NaN
# 11 -2.922579      NaN       NaN       NaN     NaN     NaN     NaN     NaN
# 12 -0.782561      NaN       NaN       NaN     NaN     NaN     NaN     NaN
# 13       NaN      NaN       NaN       NaN     NaN     NaN     NaN     NaN
# 14       NaN      NaN       NaN       NaN     NaN     NaN     NaN     NaN
# 15       NaN      NaN       NaN       NaN     NaN     NaN     NaN     NaN
# 16 -2.922579      NaN       NaN       NaN     NaN     NaN     NaN     NaN
# 17       NaN      NaN       NaN       NaN     NaN     NaN     NaN     NaN
# 18       NaN      NaN       NaN       NaN     NaN     NaN     NaN     NaN
# 19       NaN      NaN       NaN       NaN     NaN     NaN     NaN     NaN
# 20       NaN      NaN       NaN       NaN     NaN     NaN     NaN     NaN
# 21       NaN      NaN       NaN       NaN     NaN     NaN     NaN     NaN
# 22       NaN      NaN       NaN       NaN     NaN     NaN     NaN     NaN
# 23       NaN      NaN       NaN       NaN     NaN     NaN     NaN     NaN
# 24       NaN      NaN       NaN       NaN     NaN     NaN     NaN     NaN
# 25       NaN      NaN       NaN       NaN     NaN     NaN     NaN     NaN
# 26       NaN      NaN       NaN       NaN     NaN     NaN     NaN     NaN
# 27       NaN      NaN       NaN       NaN     NaN     NaN     NaN     NaN
# 28 -1.106899 -2.17472  6.694624 -0.256363     NaN     NaN     NaN     NaN
# 29 -1.106899      NaN       NaN       NaN     NaN     NaN     NaN     NaN
# 30 -0.256363      NaN       NaN       NaN     NaN     NaN     NaN     NaN
# 31 -0.577677      NaN       NaN       NaN     NaN     NaN     NaN     NaN
# 32       NaN      NaN       NaN       NaN     NaN     NaN     NaN     NaN
# 33       NaN      NaN       NaN       NaN     NaN     NaN     NaN     NaN
# 34       NaN      NaN       NaN       NaN     NaN     NaN     NaN     NaN
# 35       NaN      NaN       NaN       NaN     NaN     NaN     NaN     NaN
# 36 -2.947965      NaN       NaN       NaN     NaN     NaN     NaN     NaN
# 37 -0.577677      NaN       NaN       NaN     NaN     NaN     NaN     NaN
# 38       NaN      NaN       NaN       NaN     NaN     NaN     NaN     NaN
# 39       NaN      NaN       NaN       NaN     NaN     NaN     NaN     NaN
# 40       NaN      NaN       NaN       NaN     NaN     NaN     NaN     NaN
# 41 -2.947965      NaN       NaN       NaN     NaN     NaN     NaN     NaN
# 42       NaN      NaN       NaN       NaN     NaN     NaN     NaN     NaN
# 43       NaN      NaN       NaN       NaN     NaN     NaN     NaN     NaN
# 44       NaN      NaN       NaN       NaN     NaN     NaN     NaN     NaN
# 45       NaN      NaN       NaN       NaN     NaN     NaN     NaN     NaN
# 46       NaN      NaN       NaN       NaN     NaN     NaN     NaN     NaN
# 47       NaN      NaN       NaN       NaN     NaN     NaN     NaN     NaN
# 48       NaN      NaN       NaN       NaN     NaN     NaN     NaN     NaN
# 49       NaN      NaN       NaN       NaN     NaN     NaN     NaN     NaN
#
#     c_H4_y  c_H4_z    c_A1_x    c_A1_y    c_A1_z    c_A2_x    c_A2_y  \
# 0      NaN     NaN       NaN       NaN       NaN       NaN       NaN
# 1      NaN     NaN       NaN       NaN       NaN       NaN       NaN
# 2      NaN     NaN -3.032754 -1.324243 -5.778465 -2.235665 -1.212207
# 3      NaN     NaN       NaN       NaN       NaN       NaN       NaN
# 4      NaN     NaN       NaN       NaN       NaN       NaN       NaN
# 5      NaN     NaN       NaN       NaN       NaN       NaN       NaN
# 6      NaN     NaN       NaN       NaN       NaN       NaN       NaN
# 7      NaN     NaN       NaN       NaN       NaN       NaN       NaN
# 8      NaN     NaN       NaN       NaN       NaN       NaN       NaN
# 9      NaN     NaN -1.324393 -1.807113 -0.864033 -0.535188 -1.417178
# 10     NaN     NaN       NaN       NaN       NaN       NaN       NaN
# 11     NaN     NaN  0.215884  0.400733 -2.376462 -0.143982  0.908083
# 12     NaN     NaN       NaN       NaN       NaN       NaN       NaN
# 13     NaN     NaN       NaN       NaN       NaN       NaN       NaN
# 14     NaN     NaN       NaN       NaN       NaN       NaN       NaN
# 15     NaN     NaN       NaN       NaN       NaN       NaN       NaN
# 16     NaN     NaN       NaN       NaN       NaN       NaN       NaN
# 17     NaN     NaN       NaN       NaN       NaN       NaN       NaN
# 18     NaN     NaN       NaN       NaN       NaN       NaN       NaN
# 19     NaN     NaN       NaN       NaN       NaN       NaN       NaN
# 20     NaN     NaN  1.619456 -0.074493  2.233743  2.149055 -0.074261
# 21     NaN     NaN       NaN       NaN       NaN       NaN       NaN
# 22     NaN     NaN       NaN       NaN       NaN       NaN       NaN
# 23     NaN     NaN       NaN       NaN       NaN       NaN       NaN
# 24     NaN     NaN  0.288893 -2.995609  3.323419 -0.151901 -3.881303
# 25     NaN     NaN       NaN       NaN       NaN       NaN       NaN
# 26     NaN     NaN       NaN       NaN       NaN       NaN       NaN
# 27     NaN     NaN -0.313719  4.379061 -0.706636 -1.274804  5.015656
# 28     NaN     NaN       NaN       NaN       NaN       NaN       NaN
# 29     NaN     NaN       NaN       NaN       NaN       NaN       NaN
# 30     NaN     NaN       NaN       NaN       NaN       NaN       NaN
# 31     NaN     NaN       NaN       NaN       NaN       NaN       NaN
# 32     NaN     NaN       NaN       NaN       NaN       NaN       NaN
# 33     NaN     NaN       NaN       NaN       NaN       NaN       NaN
# 34     NaN     NaN  0.139522 -2.276296 -0.607364 -0.500051 -1.407079
# 35     NaN     NaN       NaN       NaN       NaN       NaN       NaN
# 36     NaN     NaN -0.058694  0.267166 -2.431304 -0.632257  0.437046
# 37     NaN     NaN       NaN       NaN       NaN       NaN       NaN
# 38     NaN     NaN       NaN       NaN       NaN       NaN       NaN
# 39     NaN     NaN       NaN       NaN       NaN       NaN       NaN
# 40     NaN     NaN       NaN       NaN       NaN       NaN       NaN
# 41     NaN     NaN       NaN       NaN       NaN       NaN       NaN
# 42     NaN     NaN       NaN       NaN       NaN       NaN       NaN
# 43     NaN     NaN       NaN       NaN       NaN       NaN       NaN
# 44     NaN     NaN       NaN       NaN       NaN       NaN       NaN
# 45     NaN     NaN  1.687867  1.523539  1.582630  2.168448  0.679272
# 46     NaN     NaN       NaN       NaN       NaN       NaN       NaN
# 47     NaN     NaN       NaN       NaN       NaN       NaN       NaN
# 48     NaN     NaN       NaN       NaN       NaN       NaN       NaN
# 49     NaN     NaN -4.255901 -1.926477  1.233471 -3.677174 -2.908392
#
#           c_A2_z atom_type_label        chi1        chi2        chi3  chi4  \
# 0            NaN         c_alkyl  295.600006  181.399994  346.500000   NaN
# 1            NaN              co  295.600006  181.399994  346.500000   NaN
# 2  -4.846700e+00               o  295.600006  181.399994  346.500000   NaN
# 3            NaN               n  295.600006  181.399994  346.500000   NaN
# 4            NaN           h_pol  295.600006  181.399994  346.500000   NaN
# 5            NaN           h_pol  295.600006  181.399994  346.500000   NaN
# 6            NaN               n   43.599998         NaN         NaN   NaN
# 7            NaN         c_alkyl   43.599998         NaN         NaN   NaN
# 8            NaN              co   43.599998         NaN         NaN   NaN
# 9  -1.574665e-15               o   43.599998         NaN         NaN   NaN
# 10           NaN         c_alkyl   43.599998         NaN         NaN   NaN
# 11 -2.071682e+00               o   43.599998         NaN         NaN   NaN
# 12           NaN           h_pol   43.599998         NaN         NaN   NaN
# 13           NaN         h_alkyl   43.599998         NaN         NaN   NaN
# 14           NaN         h_alkyl   43.599998         NaN         NaN   NaN
# 15           NaN         h_alkyl   43.599998         NaN         NaN   NaN
# 16           NaN           h_pol   43.599998         NaN         NaN   NaN
# 17           NaN               n         NaN         NaN         NaN   NaN
# 18           NaN         c_alkyl         NaN         NaN         NaN   NaN
# 19           NaN              co         NaN         NaN         NaN   NaN
# 20  1.128869e+00               o         NaN         NaN         NaN   NaN
# 21           NaN               n   57.900002  183.699997  328.299988   NaN
# 22           NaN         c_alkyl   57.900002  183.699997  328.299988   NaN
# 23           NaN              co   57.900002  183.699997  328.299988   NaN
# 24  2.602204e+00               o   57.900002  183.699997  328.299988   NaN
# 25           NaN         c_alkyl  173.399994   42.599998         NaN   NaN
# 26           NaN              co  173.399994   42.599998         NaN   NaN
# 27 -2.705066e-01               o  173.399994   42.599998         NaN   NaN
# 28           NaN               n  173.399994   42.599998         NaN   NaN
# 29           NaN           h_pol  173.399994   42.599998         NaN   NaN
# 30           NaN           h_pol  173.399994   42.599998         NaN   NaN
# 31           NaN               n   52.599998         NaN         NaN   NaN
# 32           NaN         c_alkyl   52.599998         NaN         NaN   NaN
# 33           NaN              co   52.599998         NaN         NaN   NaN
# 34  1.266126e-16               o   52.599998         NaN         NaN   NaN
# 35           NaN         c_alkyl   52.599998         NaN         NaN   NaN
# 36 -2.082868e+00               o   52.599998         NaN         NaN   NaN
# 37           NaN           h_pol   52.599998         NaN         NaN   NaN
# 38           NaN         h_alkyl   52.599998         NaN         NaN   NaN
# 39           NaN         h_alkyl   52.599998         NaN         NaN   NaN
# 40           NaN         h_alkyl   52.599998         NaN         NaN   NaN
# 41           NaN           h_pol   52.599998         NaN         NaN   NaN
# 42           NaN               n  176.800003   34.799999         NaN   NaN
# 43           NaN         c_alkyl  176.800003   34.799999         NaN   NaN
# 44           NaN              co  176.800003   34.799999         NaN   NaN
# 45  8.327258e-01               o  176.800003   34.799999         NaN   NaN
# 46           NaN               n  173.399994  277.299988         NaN   NaN
# 47           NaN         c_alkyl  173.399994  277.299988         NaN   NaN
# 48           NaN              co  173.399994  277.299988         NaN   NaN
# 49  7.583523e-01               o  173.399994  277.299988         NaN   NaN
#
#    evaluation rotamer   rscc    rsr   rsrz         phi         psi     rama  \
# 0     Favored     mt0  0.951  0.091 -0.957  -68.199997  -36.599998  Favored
# 1     Favored     mt0  0.951  0.091 -0.957  -68.199997  -36.599998  Favored
# 2     Favored     mt0  0.951  0.091 -0.957  -68.199997  -36.599998  Favored
# 3     Favored     mt0  0.951  0.091 -0.957  -68.199997  -36.599998  Favored
# 4     Favored     mt0  0.951  0.091 -0.957  -68.199997  -36.599998  Favored
# 5     Favored     mt0  0.951  0.091 -0.957  -68.199997  -36.599998  Favored
# 6     Favored       p  0.970  0.083 -0.856  -87.599998   53.299999  Favored
# 7     Favored       p  0.970  0.083 -0.856  -87.599998   53.299999  Favored
# 8     Favored       p  0.970  0.083 -0.856  -87.599998   53.299999  Favored
# 9     Favored       p  0.970  0.083 -0.856  -87.599998   53.299999  Favored
# 10    Favored       p  0.970  0.083 -0.856  -87.599998   53.299999  Favored
# 11    Favored       p  0.970  0.083 -0.856  -87.599998   53.299999  Favored
# 12    Favored       p  0.970  0.083 -0.856  -87.599998   53.299999  Favored
# 13    Favored       p  0.970  0.083 -0.856  -87.599998   53.299999  Favored
# 14    Favored       p  0.970  0.083 -0.856  -87.599998   53.299999  Favored
# 15    Favored       p  0.970  0.083 -0.856  -87.599998   53.299999  Favored
# 16    Favored       p  0.970  0.083 -0.856  -87.599998   53.299999  Favored
# 17        NaN     NaN  0.959  0.085 -0.709  -99.400002    7.500000  Favored
# 18        NaN     NaN  0.959  0.085 -0.709  -99.400002    7.500000  Favored
# 19        NaN     NaN  0.959  0.085 -0.709  -99.400002    7.500000  Favored
# 20        NaN     NaN  0.959  0.085 -0.709  -99.400002    7.500000  Favored
# 21    Favored     pt0  0.954  0.113 -0.639 -156.399994  179.000000  Favored
# 22    Favored     pt0  0.954  0.113 -0.639 -156.399994  179.000000  Favored
# 23    Favored     pt0  0.954  0.113 -0.639 -156.399994  179.000000  Favored
# 24    Favored     pt0  0.954  0.113 -0.639 -156.399994  179.000000  Favored
# 25    Favored      t0  0.942  0.119  0.071 -131.199997  111.400002  Favored
# 26    Favored      t0  0.942  0.119  0.071 -131.199997  111.400002  Favored
# 27    Favored      t0  0.942  0.119  0.071 -131.199997  111.400002  Favored
# 28    Favored      t0  0.942  0.119  0.071 -131.199997  111.400002  Favored
# 29    Favored      t0  0.942  0.119  0.071 -131.199997  111.400002  Favored
# 30    Favored      t0  0.942  0.119  0.071 -131.199997  111.400002  Favored
# 31    Favored       p  0.968  0.076 -0.593 -132.500000  145.899994  Favored
# 32    Favored       p  0.968  0.076 -0.593 -132.500000  145.899994  Favored
# 33    Favored       p  0.968  0.076 -0.593 -132.500000  145.899994  Favored
# 34    Favored       p  0.968  0.076 -0.593 -132.500000  145.899994  Favored
# 35    Favored       p  0.968  0.076 -0.593 -132.500000  145.899994  Favored
# 36    Favored       p  0.968  0.076 -0.593 -132.500000  145.899994  Favored
# 37    Favored       p  0.968  0.076 -0.593 -132.500000  145.899994  Favored
# 38    Favored       p  0.968  0.076 -0.593 -132.500000  145.899994  Favored
# 39    Favored       p  0.968  0.076 -0.593 -132.500000  145.899994  Favored
# 40    Favored       p  0.968  0.076 -0.593 -132.500000  145.899994  Favored
# 41    Favored       p  0.968  0.076 -0.593 -132.500000  145.899994  Favored
# 42    Favored     t60  0.942  0.101  0.033 -164.100006  130.600006  Favored
# 43    Favored     t60  0.942  0.101  0.033 -164.100006  130.600006  Favored
# 44    Favored     t60  0.942  0.101  0.033 -164.100006  130.600006  Favored
# 45    Favored     t60  0.942  0.101  0.033 -164.100006  130.600006  Favored
# 46    Favored     t80  0.951  0.101 -0.095 -144.699997  149.800003  Favored
# 47    Favored     t80  0.951  0.101 -0.095 -144.699997  149.800003  Favored
# 48    Favored     t80  0.951  0.101 -0.095 -144.699997  149.800003  Favored
# 49    Favored     t80  0.951  0.101 -0.095 -144.699997  149.800003  Favored
#
#    pdb_chain pdb_segment  pdb_resnum dssp  dssp_acc       dssp_seq  \
# 0          A           A          60    T      49.0  EEECSCTTTCSHH
# 1          A           A          60    T      49.0  EEECSCTTTCSHH
# 2          A           A          60    T      49.0  EEECSCTTTCSHH
# 3          A           A          60    T      49.0  EEECSCTTTCSHH
# 4          A           A          60    T      49.0  EEECSCTTTCSHH
# 5          A           A          60    T      49.0  EEECSCTTTCSHH
# 6          A           A          83    S      45.0  EEEECCSSCHHHH
# 7          A           A          83    S      45.0  EEEECCSSCHHHH
# 8          A           A          83    S      45.0  EEEECCSSCHHHH
# 9          A           A          83    S      45.0  EEEECCSSCHHHH
# 10         A           A          83    S      45.0  EEEECCSSCHHHH
# 11         A           A          83    S      45.0  EEEECCSSCHHHH
# 12         A           A          83    S      45.0  EEEECCSSCHHHH
# 13         A           A          83    S      45.0  EEEECCSSCHHHH
# 14         A           A          83    S      45.0  EEEECCSSCHHHH
# 15         A           A          83    S      45.0  EEEECCSSCHHHH
# 16         A           A          83    S      45.0  EEEECCSSCHHHH
# 17         A           A          82    C      11.0  EEEECCSSCHHHH
# 18         A           A          82    C      11.0  EEEECCSSCHHHH
# 19         A           A          82    C      11.0  EEEECCSSCHHHH
# 20         A           A          82    C      11.0  EEEECCSSCHHHH
# 21         A           A          84    S      44.0  EEEECCSSCHHHH
# 22         A           A          84    S      44.0  EEEECCSSCHHHH
# 23         A           A          84    S      44.0  EEEECCSSCHHHH
# 24         A           A          84    S      44.0  EEEECCSSCHHHH
# 25         A           A           7    E      39.0  CEEEEEEESSCCG
# 26         A           A           7    E      39.0  CEEEEEEESSCCG
# 27         A           A           7    E      39.0  CEEEEEEESSCCG
# 28         A           A           7    E      39.0  CEEEEEEESSCCG
# 29         A           A           7    E      39.0  CEEEEEEESSCCG
# 30         A           A           7    E      39.0  CEEEEEEESSCCG
# 31         A           A         220    E      33.0  EEEEEEEEEEEEC
# 32         A           A         220    E      33.0  EEEEEEEEEEEEC
# 33         A           A         220    E      33.0  EEEEEEEEEEEEC
# 34         A           A         220    E      33.0  EEEEEEEEEEEEC
# 35         A           A         220    E      33.0  EEEEEEEEEEEEC
# 36         A           A         220    E      33.0  EEEEEEEEEEEEC
# 37         A           A         220    E      33.0  EEEEEEEEEEEEC
# 38         A           A         220    E      33.0  EEEEEEEEEEEEC
# 39         A           A         220    E      33.0  EEEEEEEEEEEEC
# 40         A           A         220    E      33.0  EEEEEEEEEEEEC
# 41         A           A         220    E      33.0  EEEEEEEEEEEEC
# 42         A           A         219    E       3.0  EEEEEEEEEEEEC
# 43         A           A         219    E       3.0  EEEEEEEEEEEEC
# 44         A           A         219    E       3.0  EEEEEEEEEEEEC
# 45         A           A         219    E       3.0  EEEEEEEEEEEEC
# 46         A           A         221    E       5.0  EEEEEEEEEEEEC
# 47         A           A         221    E       5.0  EEEEEEEEEEEEC
# 48         A           A         221    E       5.0  EEEEEEEEEEEEC
# 49         A           A         221    E       5.0  EEEEEEEEEEEEC
#
#         ABPLE_seq ABPLE ABPLE_3mer dssp_3mer contact_hb contact_wh contact_cc  \
# 0   BBPPBBAAABPAA     A        BAA       CTT       None       None       True
# 1   BBPPBBAAABPAA     A        BAA       CTT       None       None       None
# 2   BBPPBBAAABPAA     A        BAA       CTT       None       None       None
# 3   BBPPBBAAABPAA     A        BAA       CTT       None       None       None
# 4   BBPPBBAAABPAA     A        BAA       CTT       True       True       True
# 5   BBPPBBAAABPAA     A        BAA       CTT       None       None       None
# 6   BBBPPABBPAAAA     B        ABB       CSS       None       None       None
# 7   BBBPPABBPAAAA     B        ABB       CSS       None       None       None
# 8   BBBPPABBPAAAA     B        ABB       CSS       None       None       None
# 9   BBBPPABBPAAAA     B        ABB       CSS       True       None       None
# 10  BBBPPABBPAAAA     B        ABB       CSS       None       None       None
# 11  BBBPPABBPAAAA     B        ABB       CSS       None       True       True
# 12  BBBPPABBPAAAA     B        ABB       CSS       None       None       None
# 13  BBBPPABBPAAAA     B        ABB       CSS       None       None       None
# 14  BBBPPABBPAAAA     B        ABB       CSS       None       None       True
# 15  BBBPPABBPAAAA     B        ABB       CSS       None       None       None
# 16  BBBPPABBPAAAA     B        ABB       CSS       None       None       None
# 17  BBBPPABBPAAAA     A        ABB       CSS       None       None       None
# 18  BBBPPABBPAAAA     A        ABB       CSS       None       None       None
# 19  BBBPPABBPAAAA     A        ABB       CSS       None       None       None
# 20  BBBPPABBPAAAA     A        ABB       CSS       None       None       None
# 21  BBBPPABBPAAAA     B        ABB       CSS       None       None       None
# 22  BBBPPABBPAAAA     B        ABB       CSS       None       None       None
# 23  BBBPPABBPAAAA     B        ABB       CSS       None       None       None
# 24  BBBPPABBPAAAA     B        ABB       CSS       None       None       None
# 25  nBBBBBBBABPBA     B        BBB       EEE       None       None       None
# 26  nBBBBBBBABPBA     B        BBB       EEE       None       None       None
# 27  nBBBBBBBABPBA     B        BBB       EEE       None       None       True
# 28  nBBBBBBBABPBA     B        BBB       EEE       None       None       None
# 29  nBBBBBBBABPBA     B        BBB       EEE       None       None       None
# 30  nBBBBBBBABPBA     B        BBB       EEE       None       None       None
# 31  BBBABBBBBBBBn     B        BBB       EEE       None       None       None
# 32  BBBABBBBBBBBn     B        BBB       EEE       None       None       None
# 33  BBBABBBBBBBBn     B        BBB       EEE       None       None       None
# 34  BBBABBBBBBBBn     B        BBB       EEE       None       None       None
# 35  BBBABBBBBBBBn     B        BBB       EEE       None       None       None
# 36  BBBABBBBBBBBn     B        BBB       EEE       None       None       None
# 37  BBBABBBBBBBBn     B        BBB       EEE       None       None       None
# 38  BBBABBBBBBBBn     B        BBB       EEE       None       None       None
# 39  BBBABBBBBBBBn     B        BBB       EEE       None       None       None
# 40  BBBABBBBBBBBn     B        BBB       EEE       None       None       True
# 41  BBBABBBBBBBBn     B        BBB       EEE       None       None       None
# 42  BBBABBBBBBBBn     B        BBB       EEE       None       None       None
# 43  BBBABBBBBBBBn     B        BBB       EEE       None       None       None
# 44  BBBABBBBBBBBn     B        BBB       EEE       None       None       None
# 45  BBBABBBBBBBBn     B        BBB       EEE       None       None       None
# 46  BBBABBBBBBBBn     B        BBB       EEE       None       None       None
# 47  BBBABBBBBBBBn     B        BBB       EEE       None       None       None
# 48  BBBABBBBBBBBn     B        BBB       EEE       None       None       None
# 49  BBBABBBBBBBBn     B        BBB       EEE       None       None       None
#
#    contact_so partners_hb partners_wh partners_cc partners_so  rota  CG  \
# 0        None        None        None          OG        None     1   1
# 1        None        None        None        None        None     1   1
# 2        None        None        None        None        None     1   1
# 3        None        None        None        None        None     1   1
# 4        None           O          OG         HB2        None     1   1
# 5        None        None        None        None        None     1   1
# 6        None        None        None        None        None     1   1
# 7        None        None        None        None        None     1   1
# 8        None        None        None        None        None     1   1
# 9        None        HE21        None        None        None     1   1
# 10       None        None        None        None        None     1   1
# 11       None        None        HE21          CG        None     1   1
# 12       None        None        None        None        None     1   1
# 13       None        None        None        None        None     1   1
# 14       None        None        None        HE21        None     1   1
# 15       None        None        None        None        None     1   1
# 16       None        None        None        None        None     1   1
# 17       None        None        None        None        None     1   1
# 18       None        None        None        None        None     1   1
# 19       None        None        None        None        None     1   1
# 20       None        None        None        None        None     1   1
# 21       None        None        None        None        None     1   1
# 22       None        None        None        None        None     1   1
# 23       None        None        None        None        None     1   1
# 24       None        None        None        None        None     1   1
# 25       None        None        None        None        None     1   1
# 26       None        None        None        None        None     1   1
# 27       None        None        None         HB3        None     1   1
# 28       None        None        None        None        None     1   1
# 29       None        None        None        None        None     1   1
# 30       None        None        None        None        None     1   1
# 31       None        None        None        None        None     1   1
# 32       None        None        None        None        None     1   1
# 33       None        None        None        None        None     1   1
# 34       None        None        None        None        None     1   1
# 35       None        None        None        None        None     1   1
# 36       None        None        None        None        None     1   1
# 37       None        None        None        None        None     1   1
# 38       None        None        None        None        None     1   1
# 39       None        None        None        None        None     1   1
# 40       None        None        None         OD1        None     1   1
# 41       None        None        None        None        None     1   1
# 42       None        None        None        None        None     1   1
# 43       None        None        None        None        None     1   1
# 44       None        None        None        None        None     1   1
# 45       None        None        None        None        None     1   1
# 46       None        None        None        None        None     1   1
# 47       None        None        None        None        None     1   1
# 48       None        None        None        None        None     1   1
# 49       None        None        None        None        None     1   1
#
#                             seq hull_status  dist_to_hull       pdb_name  \
# 0   LVSAIMQSVSGEK-ISFIFGSQSIESQ     exposed  8.561362e-01  1AK5_biomol_1
# 1   LVSAIMQSVSGEK-ISFIFGSQSIESQ     exposed  7.100574e-01  1AK5_biomol_1
# 2   LVSAIMQSVSGEK-ISFIFGSQSIESQ     exposed  1.670221e-01  1AK5_biomol_1
# 3   LVSAIMQSVSGEK-ISFIFGSQSIESQ     exposed  4.216247e-01  1AK5_biomol_1
# 4   LVSAIMQSVSGEK-ISFIFGSQSIESQ     exposed  3.663162e-01  1AK5_biomol_1
# 5   LVSAIMQSVSGEK-ISFIFGSQSIESQ     exposed -2.867719e-01  1AK5_biomol_1
# 6   LVSAIMQSVSGEK-ISFIFGSQSIESQ    intermed  1.859582e+00  1AK5_biomol_1
# 7   LVSAIMQSVSGEK-ISFIFGSQSIESQ    intermed  4.306102e-01  1AK5_biomol_1
# 8   LVSAIMQSVSGEK-ISFIFGSQSIESQ    intermed -1.501557e-01  1AK5_biomol_1
# 9   LVSAIMQSVSGEK-ISFIFGSQSIESQ    intermed -6.117374e-01  1AK5_biomol_1
# 10  LVSAIMQSVSGEK-ISFIFGSQSIESQ    intermed  8.504279e-07  1AK5_biomol_1
# 11  LVSAIMQSVSGEK-ISFIFGSQSIESQ    intermed  1.366179e+00  1AK5_biomol_1
# 12  LVSAIMQSVSGEK-ISFIFGSQSIESQ    intermed  2.148792e+00  1AK5_biomol_1
# 13  LVSAIMQSVSGEK-ISFIFGSQSIESQ    intermed -6.748147e-02  1AK5_biomol_1
# 14  LVSAIMQSVSGEK-ISFIFGSQSIESQ    intermed -4.767356e-01  1AK5_biomol_1
# 15  LVSAIMQSVSGEK-ISFIFGSQSIESQ    intermed  4.881699e-01  1AK5_biomol_1
# 16  LVSAIMQSVSGEK-ISFIFGSQSIESQ    intermed  1.774505e+00  1AK5_biomol_1
# 17  LVSAIMQSVSGEK-ISFIFGSQSIESQ      buried  4.425562e+00  1AK5_biomol_1
# 18  LVSAIMQSVSGEK-ISFIFGSQSIESQ      buried  3.886914e+00  1AK5_biomol_1
# 19  LVSAIMQSVSGEK-ISFIFGSQSIESQ      buried  2.385818e+00  1AK5_biomol_1
# 20  LVSAIMQSVSGEK-ISFIFGSQSIESQ      buried  1.705522e+00  1AK5_biomol_1
# 21  LVSAIMQSVSGEK-ISFIFGSQSIESQ    intermed  4.246701e-01  1AK5_biomol_1
# 22  LVSAIMQSVSGEK-ISFIFGSQSIESQ    intermed -2.097065e-01  1AK5_biomol_1
# 23  LVSAIMQSVSGEK-ISFIFGSQSIESQ    intermed  4.902350e-01  1AK5_biomol_1
# 24  LVSAIMQSVSGEK-ISFIFGSQSIESQ    intermed  6.822984e-01  1AK5_biomol_1
# 25  SNDASFNVETFNK-HNVLSWSFSSNFI     exposed -1.685623e-06  1AVB_biomol_1
# 26  SNDASFNVETFNK-HNVLSWSFSSNFI     exposed -7.748379e-01  1AVB_biomol_1
# 27  SNDASFNVETFNK-HNVLSWSFSSNFI     exposed -6.797802e-01  1AVB_biomol_1
# 28  SNDASFNVETFNK-HNVLSWSFSSNFI     exposed -1.052587e+00  1AVB_biomol_1
# 29  SNDASFNVETFNK-HNVLSWSFSSNFI     exposed -1.576443e+00  1AVB_biomol_1
# 30  SNDASFNVETFNK-HNVLSWSFSSNFI     exposed -5.979543e-01  1AVB_biomol_1
# 31  SNDASFNVETFNK-HNVLSWSFSSNFI     exposed  2.340908e+00  1AVB_biomol_1
# 32  SNDASFNVETFNK-HNVLSWSFSSNFI     exposed  1.532649e+00  1AVB_biomol_1
# 33  SNDASFNVETFNK-HNVLSWSFSSNFI     exposed  2.102483e+00  1AVB_biomol_1
# 34  SNDASFNVETFNK-HNVLSWSFSSNFI     exposed  2.390870e+00  1AVB_biomol_1
# 35  SNDASFNVETFNK-HNVLSWSFSSNFI     exposed -2.360224e-06  1AVB_biomol_1
# 36  SNDASFNVETFNK-HNVLSWSFSSNFI     exposed -3.747367e-01  1AVB_biomol_1
# 37  SNDASFNVETFNK-HNVLSWSFSSNFI     exposed  2.330368e+00  1AVB_biomol_1
# 38  SNDASFNVETFNK-HNVLSWSFSSNFI     exposed  1.938312e+00  1AVB_biomol_1
# 39  SNDASFNVETFNK-HNVLSWSFSSNFI     exposed -2.481153e-01  1AVB_biomol_1
# 40  SNDASFNVETFNK-HNVLSWSFSSNFI     exposed -1.865725e-01  1AVB_biomol_1
# 41  SNDASFNVETFNK-HNVLSWSFSSNFI     exposed -9.297457e-01  1AVB_biomol_1
# 42  SNDASFNVETFNK-HNVLSWSFSSNFI      buried  2.683017e+00  1AVB_biomol_1
# 43  SNDASFNVETFNK-HNVLSWSFSSNFI      buried  3.458282e+00  1AVB_biomol_1
# 44  SNDASFNVETFNK-HNVLSWSFSSNFI      buried  3.059642e+00  1AVB_biomol_1
# 45  SNDASFNVETFNK-HNVLSWSFSSNFI      buried  2.998868e+00  1AVB_biomol_1
# 46  SNDASFNVETFNK-HNVLSWSFSSNFI      buried  2.296920e+00  1AVB_biomol_1
# 47  SNDASFNVETFNK-HNVLSWSFSSNFI      buried  2.865079e+00  1AVB_biomol_1
# 48  SNDASFNVETFNK-HNVLSWSFSSNFI      buried  2.232184e+00  1AVB_biomol_1
# 49  SNDASFNVETFNK-HNVLSWSFSSNFI      buried  2.151471e+00  1AVB_biomol_1
#
#     score_index         probe_name  avg_bb_beta  sigma_bb_beta resname_rota  \
# 0         18909  1AK5_biomol_1_A_A    25.863594      11.639751          SER
# 1         18909  1AK5_biomol_1_A_A    25.863594      11.639751          SER
# 2         18909  1AK5_biomol_1_A_A    25.863594      11.639751          SER
# 3         18909  1AK5_biomol_1_A_A    25.863594      11.639751          SER
# 4         18909  1AK5_biomol_1_A_A    25.863594      11.639751          SER
# 5         18909  1AK5_biomol_1_A_A    25.863594      11.639751          SER
# 6         18909  1AK5_biomol_1_A_A    25.863594      11.639751          SER
# 7         18909  1AK5_biomol_1_A_A    25.863594      11.639751          SER
# 8         18909  1AK5_biomol_1_A_A    25.863594      11.639751          SER
# 9         18909  1AK5_biomol_1_A_A    25.863594      11.639751          SER
# 10        18909  1AK5_biomol_1_A_A    25.863594      11.639751          SER
# 11        18909  1AK5_biomol_1_A_A    25.863594      11.639751          SER
# 12        18909  1AK5_biomol_1_A_A    25.863594      11.639751          SER
# 13        18909  1AK5_biomol_1_A_A    25.863594      11.639751          SER
# 14        18909  1AK5_biomol_1_A_A    25.863594      11.639751          SER
# 15        18909  1AK5_biomol_1_A_A    25.863594      11.639751          SER
# 16        18909  1AK5_biomol_1_A_A    25.863594      11.639751          SER
# 17        18909  1AK5_biomol_1_A_A    25.863594      11.639751          SER
# 18        18909  1AK5_biomol_1_A_A    25.863594      11.639751          SER
# 19        18909  1AK5_biomol_1_A_A    25.863594      11.639751          SER
# 20        18909  1AK5_biomol_1_A_A    25.863594      11.639751          SER
# 21        18909  1AK5_biomol_1_A_A    25.863594      11.639751          SER
# 22        18909  1AK5_biomol_1_A_A    25.863594      11.639751          SER
# 23        18909  1AK5_biomol_1_A_A    25.863594      11.639751          SER
# 24        18909  1AK5_biomol_1_A_A    25.863594      11.639751          SER
# 25        12511  1AVB_biomol_1_A_A    17.975962       9.970360          SER
# 26        12511  1AVB_biomol_1_A_A    17.975962       9.970360          SER
# 27        12511  1AVB_biomol_1_A_A    17.975962       9.970360          SER
# 28        12511  1AVB_biomol_1_A_A    17.975962       9.970360          SER
# 29        12511  1AVB_biomol_1_A_A    17.975962       9.970360          SER
# 30        12511  1AVB_biomol_1_A_A    17.975962       9.970360          SER
# 31        12511  1AVB_biomol_1_A_A    17.975962       9.970360          SER
# 32        12511  1AVB_biomol_1_A_A    17.975962       9.970360          SER
# 33        12511  1AVB_biomol_1_A_A    17.975962       9.970360          SER
# 34        12511  1AVB_biomol_1_A_A    17.975962       9.970360          SER
# 35        12511  1AVB_biomol_1_A_A    17.975962       9.970360          SER
# 36        12511  1AVB_biomol_1_A_A    17.975962       9.970360          SER
# 37        12511  1AVB_biomol_1_A_A    17.975962       9.970360          SER
# 38        12511  1AVB_biomol_1_A_A    17.975962       9.970360          SER
# 39        12511  1AVB_biomol_1_A_A    17.975962       9.970360          SER
# 40        12511  1AVB_biomol_1_A_A    17.975962       9.970360          SER
# 41        12511  1AVB_biomol_1_A_A    17.975962       9.970360          SER
# 42        12511  1AVB_biomol_1_A_A    17.975962       9.970360          SER
# 43        12511  1AVB_biomol_1_A_A    17.975962       9.970360          SER
# 44        12511  1AVB_biomol_1_A_A    17.975962       9.970360          SER
# 45        12511  1AVB_biomol_1_A_A    17.975962       9.970360          SER
# 46        12511  1AVB_biomol_1_A_A    17.975962       9.970360          SER
# 47        12511  1AVB_biomol_1_A_A    17.975962       9.970360          SER
# 48        12511  1AVB_biomol_1_A_A    17.975962       9.970360          SER
# 49        12511  1AVB_biomol_1_A_A    17.975962       9.970360          SER
#
#     centroid  cluster_number  cluster_size  C_score_bb_ind  \
# 0      False               3           167        2.990312
# 1      False               3           167        2.990312
# 2      False               3           167        2.990312
# 3      False               3           167        2.990312
# 4      False               3           167        2.990312
# 5      False               3           167        2.990312
# 6      False               3           167        2.990312
# 7      False               3           167        2.990312
# 8      False               3           167        2.990312
# 9      False               3           167        2.990312
# 10     False               3           167        2.990312
# 11     False               3           167        2.990312
# 12     False               3           167        2.990312
# 13     False               3           167        2.990312
# 14     False               3           167        2.990312
# 15     False               3           167        2.990312
# 16     False               3           167        2.990312
# 17     False               3           167        2.990312
# 18     False               3           167        2.990312
# 19     False               3           167        2.990312
# 20     False               3           167        2.990312
# 21     False               3           167        2.990312
# 22     False               3           167        2.990312
# 23     False               3           167        2.990312
# 24     False               3           167        2.990312
# 25     False             174            26        1.130415
# 26     False             174            26        1.130415
# 27     False             174            26        1.130415
# 28     False             174            26        1.130415
# 29     False             174            26        1.130415
# 30     False             174            26        1.130415
# 31     False             174            26        1.130415
# 32     False             174            26        1.130415
# 33     False             174            26        1.130415
# 34     False             174            26        1.130415
# 35     False             174            26        1.130415
# 36     False             174            26        1.130415
# 37     False             174            26        1.130415
# 38     False             174            26        1.130415
# 39     False             174            26        1.130415
# 40     False             174            26        1.130415
# 41     False             174            26        1.130415
# 42     False             174            26        1.130415
# 43     False             174            26        1.130415
# 44     False             174            26        1.130415
# 45     False             174            26        1.130415
# 46     False             174            26        1.130415
# 47     False             174            26        1.130415
# 48     False             174            26        1.130415
# 49     False             174            26        1.130415
#
#     maxdist_to_centroid  cluster_atom  cluster_order  centroid_ABPLE_E  \
# 0              0.566527          True            7.0             False
# 1              0.566527          True            6.0             False
# 2              0.566527          True            5.0             False
# 3              0.566527          True            4.0             False
# 4              0.566527         False            NaN             False
# 5              0.566527         False            NaN             False
# 6              0.566527          True            0.0             False
# 7              0.566527          True            1.0             False
# 8              0.566527          True            2.0             False
# 9              0.566527         False            NaN             False
# 10             0.566527          True            3.0             False
# 11             0.566527         False            NaN             False
# 12             0.566527         False            NaN             False
# 13             0.566527         False            NaN             False
# 14             0.566527         False            NaN             False
# 15             0.566527         False            NaN             False
# 16             0.566527         False            NaN             False
# 17             0.566527         False            NaN             False
# 18             0.566527         False            NaN             False
# 19             0.566527         False            NaN             False
# 20             0.566527         False            NaN             False
# 21             0.566527         False            NaN             False
# 22             0.566527         False            NaN             False
# 23             0.566527         False            NaN             False
# 24             0.566527         False            NaN             False
# 25             0.517615          True            7.0             False
# 26             0.517615          True            6.0             False
# 27             0.517615          True            5.0             False
# 28             0.517615          True            4.0             False
# 29             0.517615         False            NaN             False
# 30             0.517615         False            NaN             False
# 31             0.517615          True            0.0             False
# ...
# 21                                 32                         True
# 22                                 32                         True
# 23                                 32                         True
# 24                                 32                         True
# 25                                 33                         True
# 26                                 33                         True
# 27                                 33                         True
# 28                                 33                         True
# 29                                 33                         True
# 30                                 33                         True
# 31                                 33                         True
# 32                                 33                         True
# 33                                 33                         True
# 34                                 33                         True
# 35                                 33                         True
# 36                                 33                         True
# 37                                 33                         True
# 38                                 33                         True
# 39                                 33                         True
# 40                                 33                         True
# 41                                 33                         True
# 42                                 33                         True
# 43                                 33                         True
# 44                                 33                         True
# 45                                 33                         True
# 46                                 33                         True
# 47                                 33                         True
# 48                                 33                         True
# 49                                 33                         True
#
#     CG_rep_cluster_number_medium_bb_ind  CG_rep_cluster_score_medium_bb_ind  \
# 0                                  1183                           -0.114409
# 1                                  1183                           -0.114409
# 2                                  1183                           -0.114409
# 3                                  1183                           -0.114409
# 4                                  1183                           -0.114409
# 5                                  1183                           -0.114409
# 6                                  1183                           -0.114409
# 7                                  1183                           -0.114409
# 8                                  1183                           -0.114409
# 9                                  1183                           -0.114409
# 10                                 1183                           -0.114409
# 11                                 1183                           -0.114409
# 12                                 1183                           -0.114409
# 13                                 1183                           -0.114409
# 14                                 1183                           -0.114409
# 15                                 1183                           -0.114409
# 16                                 1183                           -0.114409
# 17                                 1183                           -0.114409
# 18                                 1183                           -0.114409
# 19                                 1183                           -0.114409
# 20                                 1183                           -0.114409
# 21                                 1183                           -0.114409
# 22                                 1183                           -0.114409
# 23                                 1183                           -0.114409
# 24                                 1183                           -0.114409
# 25                                 1184                           -0.114409
# 26                                 1184                           -0.114409
# 27                                 1184                           -0.114409
# 28                                 1184                           -0.114409
# 29                                 1184                           -0.114409
# 30                                 1184                           -0.114409
# 31                                 1184                           -0.114409
# 32                                 1184                           -0.114409
# 33                                 1184                           -0.114409
# 34                                 1184                           -0.114409
# 35                                 1184                           -0.114409
# 36                                 1184                           -0.114409
# 37                                 1184                           -0.114409
# 38                                 1184                           -0.114409
# 39                                 1184                           -0.114409
# 40                                 1184                           -0.114409
# 41                                 1184                           -0.114409
# 42                                 1184                           -0.114409
# 43                                 1184                           -0.114409
# 44                                 1184                           -0.114409
# 45                                 1184                           -0.114409
# 46                                 1184                           -0.114409
# 47                                 1184                           -0.114409
# 48                                 1184                           -0.114409
# 49                                 1184                           -0.114409
#
#     CG_rep_centroid_medium_bb_ind  sc_rep_fine_bb_ind  CG_rep_medium_bb_ind  \
# 0                            True                True                  True
# 1                            True                True                  True
# 2                            True                True                  True
# 3                            True                True                  True
# 4                            True                True                  True
# 5                            True                True                  True
# 6                            True                True                  True
# 7                            True                True                  True
# 8                            True                True                  True
# 9                            True                True                  True
# 10                           True                True                  True
# 11                           True                True                  True
# 12                           True                True                  True
# 13                           True                True                  True
# 14                           True                True                  True
# 15                           True                True                  True
# 16                           True                True                  True
# 17                           True                True                  True
# 18                           True                True                  True
# 19                           True                True                  True
# 20                           True                True                  True
# 21                           True                True                  True
# 22                           True                True                  True
# 23                           True                True                  True
# 24                           True                True                  True
# 25                           True                True                  True
# 26                           True                True                  True
# 27                           True                True                  True
# 28                           True                True                  True
# 29                           True                True                  True
# 30                           True                True                  True
# 31                           True                True                  True
# 32                           True                True                  True
# 33                           True                True                  True
# 34                           True                True                  True
# 35                           True                True                  True
# 36                           True                True                  True
# 37                           True                True                  True
# 38                           True                True                  True
# 39                           True                True                  True
# 40                           True                True                  True
# 41                           True                True                  True
# 42                           True                True                  True
# 43                           True                True                  True
# 44                           True                True                  True
# 45                           True                True                  True
# 46                           True                True                  True
# 47                           True                True                  True
# 48                           True                True                  True
# 49                           True                True                  True
#
#     CG_rep_cluster_number_coarse_bb_ind  CG_rep_fine_bb_ind  \
# 0                                   154                True
# 1                                   154                True
# 2                                   154                True
# 3                                   154                True
# 4                                   154                True
# 5                                   154                True
# 6                                   154                True
# 7                                   154                True
# 8                                   154                True
# 9                                   154                True
# 10                                  154                True
# 11                                  154                True
# 12                                  154                True
# 13                                  154                True
# 14                                  154                True
# 15                                  154                True
# 16                                  154                True
# 17                                  154                True
# 18                                  154                True
# 19                                  154                True
# 20                                  154                True
# 21                                  154                True
# 22                                  154                True
# 23                                  154                True
# 24                                  154                True
# 25                                  235                True
# 26                                  235                True
# 27                                  235                True
# 28                                  235                True
# 29                                  235                True
# 30                                  235                True
# 31                                  235                True
# 32                                  235                True
# 33                                  235                True
# 34                                  235                True
# 35                                  235                True
# 36                                  235                True
# 37                                  235                True
# 38                                  235                True
# 39                                  235                True
# 40                                  235                True
# 41                                  235                True
# 42                                  235                True
# 43                                  235                True
# 44                                  235                True
# 45                                  235                True
# 46                                  235                True
# 47                                  235                True
# 48                                  235                True
# 49                                  235                True
#
#     sc_rep_cluster_score_fine_bb_ind contact_type
# 0                                0.0      phi_psi
# 1                                0.0      phi_psi
# 2                                0.0      phi_psi
# 3                                0.0      phi_psi
# 4                                0.0      phi_psi
# 5                                0.0      phi_psi
# 6                                0.0      phi_psi
# 7                                0.0      phi_psi
# 8                                0.0      phi_psi
# 9                                0.0      phi_psi
# 10                               0.0      phi_psi
# 11                               0.0      phi_psi
# 12                               0.0      phi_psi
# 13                               0.0      phi_psi
# 14                               0.0      phi_psi
# 15                               0.0      phi_psi
# 16                               0.0      phi_psi
# 17                               0.0      phi_psi
# 18                               0.0      phi_psi
# 19                               0.0      phi_psi
# 20                               0.0      phi_psi
# 21                               0.0      phi_psi
# 22                               0.0      phi_psi
# 23                               0.0      phi_psi
# 24                               0.0      phi_psi
# 25                               0.0           sc
# 26                               0.0           sc
# 27                               0.0           sc
# 28                               0.0           sc
# 29                               0.0           sc
# 30                               0.0           sc
# 31                               0.0           sc
# 32                               0.0           sc
# 33                               0.0           sc
# 34                               0.0           sc
# 35                               0.0           sc
# 36                               0.0           sc
# 37                               0.0           sc
# 38                               0.0           sc
# 39                               0.0           sc
# 40                               0.0           sc
# 41                               0.0           sc
# 42                               0.0           sc
# 43                               0.0           sc
# 44                               0.0           sc
# 45                               0.0           sc
# 46                               0.0           sc
# 47                               0.0           sc
# 48                               0.0           sc
# 49                               0.0           sc

# %% [markdown]
# Here are only the first few rows of the dataframe, which makes it easier to scroll through all the columns.

# %%
df.head(3)
# Out:
#    resnum chain resname name       beta  occ       c_x       c_y       c_z  \
# 0      10     Y     GLN   CG  30.020000  1.0 -0.751365 -1.069795 -5.110119
# 1      10     Y     GLN   CD  31.900000  1.0 -2.235665 -1.212207 -4.846700
# 2      10     Y     GLN  OE1  36.459999  1.0 -3.032754 -1.324243 -5.778465
#
#    c_D_x  c_D_y  c_D_z  c_H1_x  c_H1_y  c_H1_z  c_H2_x  c_H2_y  c_H2_z  \
# 0    NaN    NaN    NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1    NaN    NaN    NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2    NaN    NaN    NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
#    c_H3_x  c_H3_y  c_H3_z  c_H4_x  c_H4_y  c_H4_z    c_A1_x    c_A1_y  \
# 0     NaN     NaN     NaN     NaN     NaN     NaN       NaN       NaN
# 1     NaN     NaN     NaN     NaN     NaN     NaN       NaN       NaN
# 2     NaN     NaN     NaN     NaN     NaN     NaN -3.032754 -1.324243
#
#      c_A1_z    c_A2_x    c_A2_y  c_A2_z atom_type_label        chi1  \
# 0       NaN       NaN       NaN     NaN         c_alkyl  295.600006
# 1       NaN       NaN       NaN     NaN              co  295.600006
# 2 -5.778465 -2.235665 -1.212207 -4.8467               o  295.600006
#
#          chi2   chi3  chi4 evaluation rotamer   rscc    rsr   rsrz        phi  \
# 0  181.399994  346.5   NaN    Favored     mt0  0.951  0.091 -0.957 -68.199997
# 1  181.399994  346.5   NaN    Favored     mt0  0.951  0.091 -0.957 -68.199997
# 2  181.399994  346.5   NaN    Favored     mt0  0.951  0.091 -0.957 -68.199997
#
#          psi     rama pdb_chain pdb_segment  pdb_resnum dssp  dssp_acc  \
# 0 -36.599998  Favored         A           A          60    T      49.0
# 1 -36.599998  Favored         A           A          60    T      49.0
# 2 -36.599998  Favored         A           A          60    T      49.0
#
#         dssp_seq      ABPLE_seq ABPLE ABPLE_3mer dssp_3mer contact_hb  \
# 0  EEECSCTTTCSHH  BBPPBBAAABPAA     A        BAA       CTT       None
# 1  EEECSCTTTCSHH  BBPPBBAAABPAA     A        BAA       CTT       None
# 2  EEECSCTTTCSHH  BBPPBBAAABPAA     A        BAA       CTT       None
#
#   contact_wh contact_cc contact_so partners_hb partners_wh partners_cc  \
# 0       None       True       None        None        None          OG
# 1       None       None       None        None        None        None
# 2       None       None       None        None        None        None
#
#   partners_so  rota  CG                          seq hull_status  \
# 0        None     1   1  LVSAIMQSVSGEK-ISFIFGSQSIESQ     exposed
# 1        None     1   1  LVSAIMQSVSGEK-ISFIFGSQSIESQ     exposed
# 2        None     1   1  LVSAIMQSVSGEK-ISFIFGSQSIESQ     exposed
#
#    dist_to_hull       pdb_name  score_index         probe_name  avg_bb_beta  \
# 0      0.856136  1AK5_biomol_1        18909  1AK5_biomol_1_A_A    25.863594
# 1      0.710057  1AK5_biomol_1        18909  1AK5_biomol_1_A_A    25.863594
# 2      0.167022  1AK5_biomol_1        18909  1AK5_biomol_1_A_A    25.863594
#
#    sigma_bb_beta resname_rota  centroid  cluster_number  cluster_size  \
# 0      11.639751          SER     False               3           167
# 1      11.639751          SER     False               3           167
# 2      11.639751          SER     False               3           167
#
#    C_score_bb_ind  maxdist_to_centroid  cluster_atom  cluster_order  \
# 0        2.990312             0.566527          True            7.0
# 1        2.990312             0.566527          True            6.0
# 2        2.990312             0.566527          True            5.0
#
#    centroid_ABPLE_E  centroid_ABPLE_L  centroid_ABPLE_A  centroid_ABPLE_P  \
# 0             False             False             False             False
# 1             False             False             False             False
# 2             False             False             False             False
#
#    centroid_ABPLE_B  centroid_dssp_E  centroid_dssp_I  centroid_dssp_T  \
# 0             False            False            False            False
# 1             False            False            False            False
# 2             False            False            False            False
#
#    centroid_dssp_C  centroid_dssp_S  centroid_dssp_H  centroid_dssp_G  \
# 0            False            False            False            False
# 1            False            False            False            False
# 2            False            False            False            False
#
#    centroid_dssp_B  centroid_hb_bb_ind  C_score_ABPLE_A  C_score_ABPLE_B  \
# 0            False               False         1.365524         3.219344
# 1            False               False         1.365524         3.219344
# 2            False               False         1.365524         3.219344
#
#    C_score_ABPLE_E  C_score_ABPLE_L  C_score_ABPLE_P  C_score_dssp_B  \
# 0              NaN              NaN         1.633937        1.251168
# 1              NaN              NaN         1.633937        1.251168
# 2              NaN              NaN         1.633937        1.251168
#
#    C_score_dssp_C  C_score_dssp_E  C_score_dssp_G  C_score_dssp_H  \
# 0        1.745052        3.357769       -0.578231       -0.657955
# 1        1.745052        3.357769       -0.578231       -0.657955
# 2        1.745052        3.357769       -0.578231       -0.657955
#
#    C_score_dssp_I  C_score_dssp_S  C_score_dssp_T  C_score_hb_ABPLE_A  \
# 0             NaN        0.735962        1.567238              1.1784
# 1             NaN        0.735962        1.567238              1.1784
# 2             NaN        0.735962        1.567238              1.1784
#
#    C_score_hb_ABPLE_B  C_score_hb_ABPLE_E  C_score_hb_ABPLE_L  \
# 0            2.928924                 NaN                 NaN
# 1            2.928924                 NaN                 NaN
# 2            2.928924                 NaN                 NaN
#
#    C_score_hb_ABPLE_P  C_score_hb_bb_ind  C_score_hb_dssp_B  \
# 0            1.539716           2.733022           0.309661
# 1            1.539716           2.733022           0.309661
# 2            1.539716           2.733022           0.309661
#
#    C_score_hb_dssp_C  C_score_hb_dssp_E  C_score_hb_dssp_G  C_score_hb_dssp_H  \
# 0           1.665704           3.035648          -0.693147          -0.780463
# 1           1.665704           3.035648          -0.693147          -0.780463
# 2           1.665704           3.035648          -0.693147          -0.780463
#
#    C_score_hb_dssp_I  C_score_hb_dssp_S  C_score_hb_dssp_T  \
# 0                NaN           0.707694               1.48
# 1                NaN           0.707694               1.48
# 2                NaN           0.707694               1.48
#
#    cluster_rank_ABPLE_A  cluster_rank_ABPLE_B  cluster_rank_ABPLE_E  \
# 0                  74.0                   2.0                   NaN
# 1                  74.0                   2.0                   NaN
# 2                  74.0                   2.0                   NaN
#
#    cluster_rank_ABPLE_L  cluster_rank_ABPLE_P  cluster_rank_dssp_B  \
# 0                   NaN                  24.0                  4.0
# 1                   NaN                  24.0                  4.0
# 2                   NaN                  24.0                  4.0
#
#    cluster_rank_dssp_C  cluster_rank_dssp_E  cluster_rank_dssp_G  \
# 0                 30.0                  2.0                381.0
# 1                 30.0                  2.0                381.0
# 2                 30.0                  2.0                381.0
#
#    cluster_rank_dssp_H  cluster_rank_dssp_I  cluster_rank_dssp_S  \
# 0                470.0                  NaN                 95.0
# 1                470.0                  NaN                 95.0
# 2                470.0                  NaN                 95.0
#
#    cluster_rank_dssp_T  cluster_rank_hb_ABPLE_A  cluster_rank_hb_ABPLE_B  \
# 0                 17.0                     56.0                      3.0
# 1                 17.0                     56.0                      3.0
# 2                 17.0                     56.0                      3.0
#
#    cluster_rank_hb_ABPLE_E  cluster_rank_hb_ABPLE_L  cluster_rank_hb_ABPLE_P  \
# 0                      NaN                      NaN                     14.0
# 1                      NaN                      NaN                     14.0
# 2                      NaN                      NaN                     14.0
#
#    cluster_rank_hb_bb_ind  cluster_rank_hb_dssp_B  cluster_rank_hb_dssp_C  \
# 0                     4.0                    16.0                    20.0
# 1                     4.0                    16.0                    20.0
# 2                     4.0                    16.0                    20.0
#
#    cluster_rank_hb_dssp_E  cluster_rank_hb_dssp_G  cluster_rank_hb_dssp_H  \
# 0                     2.0                   182.0                   284.0
# 1                     2.0                   182.0                   284.0
# 2                     2.0                   182.0                   284.0
#
#    cluster_rank_hb_dssp_I  cluster_rank_hb_dssp_S  cluster_rank_hb_dssp_T  \
# 0                     NaN                    38.0                    12.0
# 1                     NaN                    38.0                    12.0
# 2                     NaN                    38.0                    12.0
#
#    CG_rep_centroid_coarse_ABPLE  CG_rep_cluster_number_coarse_ABPLE  \
# 0                         False                                 133
# 1                         False                                 133
# 2                         False                                 133
#
#    CG_rep_cluster_size_coarse_ABPLE  CG_rep_cluster_score_coarse_ABPLE  \
# 0                                13                           0.781681
# 1                                13                           0.781681
# 2                                13                           0.781681
#
#    CG_rep_centroid_medium_ABPLE  CG_rep_cluster_number_medium_ABPLE  \
# 0                          True                                 450
# 1                          True                                 450
# 2                          True                                 450
#
#    CG_rep_cluster_size_medium_ABPLE  CG_rep_cluster_score_medium_ABPLE  \
# 0                                 1                          -0.124999
# 1                                 1                          -0.124999
# 2                                 1                          -0.124999
#
#    CG_rep_medium_ABPLE  CG_rep_centroid_fine_ABPLE  \
# 0                 True                        True
# 1                 True                        True
# 2                 True                        True
#
#    CG_rep_cluster_number_fine_ABPLE  CG_rep_cluster_size_fine_ABPLE  \
# 0                                13                               1
# 1                                13                               1
# 2                                13                               1
#
#    CG_rep_cluster_score_fine_ABPLE  CG_rep_fine_ABPLE  \
# 0                        -0.001881               True
# 1                        -0.001881               True
# 2                        -0.001881               True
#
#    sc_rep_centroid_fine_ABPLE  sc_rep_cluster_number_fine_ABPLE  \
# 0                        True                                 1
# 1                        True                                 1
# 2                        True                                 1
#
#    sc_rep_cluster_size_fine_ABPLE  sc_rep_cluster_score_fine_ABPLE  \
# 0                               1                              0.0
# 1                               1                              0.0
# 2                               1                              0.0
#
#    sc_rep_fine_ABPLE  sc_rep_centroid_fine_dssp  \
# 0               True                       True
# 1               True                       True
# 2               True                       True
#
#    CG_rep_cluster_size_coarse_dssp  CG_rep_cluster_score_fine_dssp  \
# 0                                2                       -0.000453
# 1                                2                       -0.000453
# 2                                2                       -0.000453
#
#    sc_rep_fine_dssp  CG_rep_fine_dssp  sc_rep_cluster_score_fine_dssp  \
# 0              True              True                             0.0
# 1              True              True                             0.0
# 2              True              True                             0.0
#
#    CG_rep_cluster_score_medium_dssp  sc_rep_cluster_size_fine_dssp  \
# 0                         -0.050196                              1
# 1                         -0.050196                              1
# 2                         -0.050196                              1
#
#    CG_rep_centroid_coarse_dssp  CG_rep_cluster_number_fine_dssp  \
# 0                         True                                2
# 1                         True                                2
# 2                         True                                2
#
#    CG_rep_cluster_number_coarse_dssp  CG_rep_cluster_size_fine_dssp  \
# 0                                257                              1
# 1                                257                              1
# 2                                257                              1
#
#    sc_rep_cluster_number_fine_dssp  CG_rep_cluster_number_medium_dssp  \
# 0                                1                                 66
# 1                                1                                 66
# 2                                1                                 66
#
#    CG_rep_cluster_size_medium_dssp  CG_rep_cluster_score_coarse_dssp  \
# 0                                1                         -0.289194
# 1                                1                         -0.289194
# 2                                1                         -0.289194
#
#    CG_rep_centroid_medium_dssp  CG_rep_centroid_fine_dssp  CG_rep_medium_dssp  \
# 0                         True                       True                True
# 1                         True                       True                True
# 2                         True                       True                True
#
#    CG_rep_cluster_score_fine_bb_ind  CG_rep_cluster_size_fine_bb_ind  \
# 0                         -0.001801                                1
# 1                         -0.001801                                1
# 2                         -0.001801                                1
#
#    sc_rep_cluster_number_fine_bb_ind  CG_rep_cluster_score_coarse_bb_ind  \
# 0                                  1                            1.134065
# 1                                  1                            1.134065
# 2                                  1                            1.134065
#
#    sc_rep_centroid_fine_bb_ind  CG_rep_cluster_size_medium_bb_ind  \
# 0                         True                                  1
# 1                         True                                  1
# 2                         True                                  1
#
#    CG_rep_centroid_coarse_bb_ind  CG_rep_cluster_size_coarse_bb_ind  \
# 0                          False                                 30
# 1                          False                                 30
# 2                          False                                 30
#
#    sc_rep_cluster_size_fine_bb_ind  CG_rep_cluster_number_fine_bb_ind  \
# 0                                1                                 32
# 1                                1                                 32
# 2                                1                                 32
#
#    CG_rep_centroid_fine_bb_ind  CG_rep_cluster_number_medium_bb_ind  \
# 0                         True                                 1183
# 1                         True                                 1183
# 2                         True                                 1183
#
#    CG_rep_cluster_score_medium_bb_ind  CG_rep_centroid_medium_bb_ind  \
# 0                           -0.114409                           True
# 1                           -0.114409                           True
# 2                           -0.114409                           True
#
#    sc_rep_fine_bb_ind  CG_rep_medium_bb_ind  \
# 0                True                  True
# 1                True                  True
# 2                True                  True
#
#    CG_rep_cluster_number_coarse_bb_ind  CG_rep_fine_bb_ind  \
# 0                                  154                True
# 1                                  154                True
# 2                                  154                True
#
#    sc_rep_cluster_score_fine_bb_ind contact_type
# 0                               0.0      phi_psi
# 1                               0.0      phi_psi
# 2                               0.0      phi_psi

# %% [markdown]
# ***Note:*** The **pdb_resnum** and **pdb_chain** columns of the dataframes refer to the raw residue number and chain in the pdb library that was searched.  However, some of the PDB files had their chain names changed to unique letters, so the chain identifier may not correspond to the same one in the PDB file (if you were to re-download it from the RCSB, for example).
#
# vdM instances can be printed as a PDB file by first selecting a unique instance from its identifier tags.  For example, the first vdM instance is:

# %%
df[['CG', 'rota', 'probe_name']].iloc[0]
# Out:
# CG                            1
# rota                          1
# probe_name    1AK5_biomol_1_A_A
# Name: 0, dtype: object

# %% [markdown]
# To print this vdM instance:

# %%
v = df[(df['CG'] == 1) & (df['rota'] == 1) & (df['probe_name'] == '5KRD_biomol_2_A_A')]
vdM_output_dir = input_dir + 'vdM/'
combs2.design.functions.print_dataframe(v, outpath=vdM_output_dir, tag='_ser_conh2')

# %% [markdown]
# vdM clusters can also be printed as PDB files:

# %%
clu_output_dir = input_dir + 'vdM_cluster_1/'
combs2.design.functions.print_cluster(df, cluster_num=1, max_members=30, outpath=clu_output_dir, tag='_ser_conh2')

# %% [markdown]
# ### Load vdMs onto the template backbone, removing clashing vdMs.

# %%
s.load_vdms(template, filter_by_phi_psi=False, run_parallel=False)
# Out:
# Loading bb_cco
# Loaded  36301 vdMs of bb_cco
# Loading conh2
# Loaded  17611 vdMs of conh2

# %% [markdown]
# ### Set ligand atoms <---> CG atoms correspondence for lookup in NearestNeighbors objects of CGs, which are created in next step.

# %%
path_to_ligand_file = input_dir + 'ligand.txt'
s.set_ligand_vdm_correspondence(path_to_ligand_file)

# %% [markdown]
# ### Create and fit NearestNeighbors objects for each CG type loaded.
# Neighbors are defined by a distance metric, here RMSD in Angstroms, which is tunable.

# %%
s.set_cg_neighbors(max_dist_criterion=True, cg_max_dists=dict(conh2=0.8, bb_cco=0.8))
# Out:
# Setting neighbors...

# %% [markdown]
# ### Load vdM-superimposed ligands onto the template backbone, removing clashing ligands and those ligands that do not pass a burial filter.

# %%
path_to_ligand_database='/Volumes/disk1/Combs2/database/20211005/lig_vdMs/apixaban/GG2/enriched/'

# %%
# #Uncomment this cell to load ligands from the precomputed database
# s.load_ligands(template, use_ligs_of_loaded_vdms_only=True,
#                     frac_non_hb_heavy_buried=0.5,
#                     path_to_ligand_database=path_to_ligand_database,
#                     hull_tolerance=0,
#                     run_parallel=False)

# %% [markdown]
# If loading ligands in parallel is desirable, it can currently be done the following way.

# %%
# #Uncomment this cell to load ligands in parallel from the precomputed database
# s_ligs = s.__copy__(no_vdms=True)
# s_ligs.load_ligands(template, use_ligs_of_loaded_vdms_only=True,
#                     frac_non_hb_heavy_buried=0.5,
#                     path_to_ligand_database=path_to_ligand_database,
#                     hull_tolerance=0,
#                     run_parallel=True)
# s.set_loaded_ligand_data(s_ligs)
# Out:
# Loading ligands of bb_cco
#     cg_group 2
#     cg_group 3
#     cg_group 4
#     cg_group 1
#     cg_group 5
# Loading ligands of conh2
#     cg_group 1
# Loaded  142 ligands

# %% [markdown]
# ### Load ligands by superimposing on-the-fly
#
# Pre-computed ligand libraries can speed up the loading process but do not need to be made.  Instead, one ligand conformer can be loaded, and this conformer can be superimposed onto CGs of loaded vdMs.  Here's how.

# %%
lig_dir = '/Users/npolizzi/Projects/design/Combs2/tutorials/files/HPC_scripts/superpose_ligand/'

s.load_ligand_conformer(path_to_lig_pdb=lig_dir + 'GG2.pdb', 
                        path_to_lig_params=lig_dir + 'GG2.params',
                        lig_resname='GG2', 
                        remove_atom_from_hb_dict=['N2', 'N5'], 
                        ligand_dataframe=None)
# Out:
# @> 59 atoms and 1 coordinate set(s) were parsed in 0.00s.

# %% [markdown]
# Ligand atom types and H-bonding atoms are automatically generated from the params file.  Here, two atoms (N2 and N5) that get marked by the code as H-bonding in the ligand (and are not really H-bonding) are removed from the H-bonding dictionary that tells Combs which atoms can H-bond.
#
# The ligand conformer can also be loaded as a pandas dataframe with the *ligand_dataframe* option, where the atom types and H-bonding atoms can be set manually, if desired.
#
# Multiple conformers can be loaded together by listing multiple pdb paths and using *load_ligand_conformers*:

# %%
pdb_paths = [lig_dir + 'GG2.pdb', ] # add more pdb paths to this list if desired.

s.load_ligand_conformers(paths_to_lig_pdbs=pdb_paths, 
                         path_to_lig_params=lig_dir + 'GG2.params',
                         lig_resname='GG2', 
                         remove_atom_from_hb_dict=['N2', 'N5'], 
                         ligand_dataframes=None)
# Out:
# @> 59 atoms and 1 coordinate set(s) were parsed in 0.00s.

# %% [markdown]
# The loaded conformer gets stored in the *ligand_conformers* attribute of the **Sample** object:

# %%
s.ligand_conformers[0]
# Out:
#     resnum chain segment resname  name        c_x        c_y        c_z  \
# 0        1     B       A     GG2    C1  28.888000  25.850000  14.054000
# 1        1     B       A     GG2   C10  32.425999  23.558001  18.648001
# 2        1     B       A     GG2   C11  33.776001  23.631001  19.343000
# 3        1     B       A     GG2   C12  31.372000  22.576000  18.958000
# 4        1     B       A     GG2   C13  30.294001  22.912001  18.093000
# 5        1     B       A     GG2   C14  25.664000  19.604000  18.638000
# 6        1     B       A     GG2   C15  27.289000  25.870001  12.400000
# 7        1     B       A     GG2   C16  25.964001  18.275000  18.173000
# 8        1     B       A     GG2   C17  31.273001  21.423000  19.955000
# 9        1     B       A     GG2   C18  27.238001  17.816999  17.879999
# 10       1     B       A     GG2   C19  24.129000  17.025999  19.239000
# 11       1     B       A     GG2    C2  29.521000  26.663000  14.990000
# 12       1     B       A     GG2   C20  24.441999  16.916000  16.523001
# 13       1     B       A     GG2   C21  23.257999  15.919000  16.587000
# 14       1     B       A     GG2   C22  28.309000  18.688000  18.059000
# 15       1     B       A     GG2   C23  22.847000  16.091000  19.052999
# 16       1     B       A     GG2   C24  30.459000  20.334999  19.181999
# 17       1     B       A     GG2   C25  22.271999  16.343000  17.688000
# 18       1     B       A     GG2    C3  30.160000  26.066999  16.089001
# 19       1     B       A     GG2    C4  30.030001  24.673000  16.181000
# 20       1     B       A     GG2   C44  26.754000  20.500999  18.861000
# 21       1     B       A     GG2    C5  29.424000  23.816000  15.214000
# 22       1     B       A     GG2    C6  28.801001  24.447001  14.105000
# 23       1     B       A     GG2    C7  28.027000  19.987000  18.532000
# 24       1     B       A     GG2    C8  28.993000  22.187000  18.011999
# 25       1     B       A     GG2    N1  30.704000  24.052999  17.268000
# 26       1     B       A     GG2    N2  24.844999  17.420000  17.968000
# 27       1     B       A     GG2    N3  34.709000  24.506001  18.642000
# 28       1     B       A     GG2    N5  29.120001  20.854000  18.638000
# 29       1     B       A     GG2    N6  32.025002  24.461000  17.629000
# 30       1     B       A     GG2    O1  33.995998  23.049000  20.295000
# 31       1     B       A     GG2    O2  24.540001  17.396000  20.274000
# 32       1     B       A     GG2    O3  28.049000  22.641001  17.554001
# 33       1     B       A     GG2    O4  28.336000  26.542999  12.987000
# 34       1     B       A     GG2    H2  29.545000  27.586000  14.873000
# 35       1     B       A     GG2    H3  30.584000  26.569000  16.747000
# 36       1     B       A     GG2   H14  24.790001  19.857000  18.827999
# 37       1     B       A     GG2   H18  27.372999  16.952999  17.562000
# 38       1     B       A     GG2   H22  29.179001  18.427000  17.860001
# 39       1     B       A     GG2   H44  26.627001  21.379999  19.138000
# 40       1     B       A     GG2    H5  29.402000  22.893000  15.325000
# 41       1     B       A     GG2    H6  28.365999  23.954000  13.447000
# 42       1     B       A     GG2  H151  26.701000  25.521000  13.089000
# 43       1     B       A     GG2  H152  26.792000  26.479000  11.832000
# 44       1     B       A     GG2  H153  27.632000  25.136999  11.866000
# 45       1     B       A     GG2  H171  30.795000  21.702000  20.750999
# 46       1     B       A     GG2  H172  32.157001  21.091000  20.177999
# 47       1     B       A     GG2  H201  24.184999  17.677999  15.982000
# 48       1     B       A     GG2  H202  25.204000  16.475000  16.117001
# 49       1     B       A     GG2  H211  23.596001  15.032000  16.784000
# 50       1     B       A     GG2  H212  22.799000  15.912000  15.733000
# 51       1     B       A     GG2  H231  23.110001  15.160000  19.128000
# 52       1     B       A     GG2  H232  22.187000  16.305000  19.730000
# 53       1     B       A     GG2  H241  30.993000  20.058001  18.421000
# 54       1     B       A     GG2  H242  30.261999  19.621000  19.808001
# 55       1     B       A     GG2  H251  21.426001  15.914000  17.708000
# 56       1     B       A     GG2  H252  22.125000  17.298000  17.599001
# 57       1     B       A     GG2  HN31  35.504002  24.620001  18.948000
# 58       1     B       A     GG2  HN32  34.462002  24.909000  17.924000
#
#      c_D_x      c_D_y   c_D_z     c_H1_x     c_H1_y  c_H1_z     c_H2_x  \
# 0      NaN        NaN     NaN        NaN        NaN     NaN        NaN
# 1      NaN        NaN     NaN        NaN        NaN     NaN        NaN
# 2      NaN        NaN     NaN        NaN        NaN     NaN        NaN
# 3      NaN        NaN     NaN        NaN        NaN     NaN        NaN
# 4      NaN        NaN     NaN        NaN        NaN     NaN        NaN
# 5      NaN        NaN     NaN        NaN        NaN     NaN        NaN
# 6      NaN        NaN     NaN        NaN        NaN     NaN        NaN
# 7      NaN        NaN     NaN        NaN        NaN     NaN        NaN
# 8      NaN        NaN     NaN        NaN        NaN     NaN        NaN
# 9      NaN        NaN     NaN        NaN        NaN     NaN        NaN
# 10     NaN        NaN     NaN        NaN        NaN     NaN        NaN
# 11     NaN        NaN     NaN        NaN        NaN     NaN        NaN
# 12     NaN        NaN     NaN        NaN        NaN     NaN        NaN
# 13     NaN        NaN     NaN        NaN        NaN     NaN        NaN
# 14     NaN        NaN     NaN        NaN        NaN     NaN        NaN
# 15     NaN        NaN     NaN        NaN        NaN     NaN        NaN
# 16     NaN        NaN     NaN        NaN        NaN     NaN        NaN
# 17     NaN        NaN     NaN        NaN        NaN     NaN        NaN
# 18     NaN        NaN     NaN        NaN        NaN     NaN        NaN
# 19     NaN        NaN     NaN        NaN        NaN     NaN        NaN
# 20     NaN        NaN     NaN        NaN        NaN     NaN        NaN
# 21     NaN        NaN     NaN        NaN        NaN     NaN        NaN
# 22     NaN        NaN     NaN        NaN        NaN     NaN        NaN
# 23     NaN        NaN     NaN        NaN        NaN     NaN        NaN
# 24     NaN        NaN     NaN        NaN        NaN     NaN        NaN
# 25     NaN        NaN     NaN        NaN        NaN     NaN        NaN
# 26     NaN        NaN     NaN        NaN        NaN     NaN        NaN
# 27  34.709  24.506001  18.642  35.504002  24.620001  18.948  34.462002
# 28     NaN        NaN     NaN        NaN        NaN     NaN        NaN
# 29     NaN        NaN     NaN        NaN        NaN     NaN        NaN
# 30     NaN        NaN     NaN        NaN        NaN     NaN        NaN
# 31     NaN        NaN     NaN        NaN        NaN     NaN        NaN
# 32     NaN        NaN     NaN        NaN        NaN     NaN        NaN
# 33     NaN        NaN     NaN        NaN        NaN     NaN        NaN
# 34     NaN        NaN     NaN        NaN        NaN     NaN        NaN
# 35     NaN        NaN     NaN        NaN        NaN     NaN        NaN
# 36     NaN        NaN     NaN        NaN        NaN     NaN        NaN
# 37     NaN        NaN     NaN        NaN        NaN     NaN        NaN
# 38     NaN        NaN     NaN        NaN        NaN     NaN        NaN
# 39     NaN        NaN     NaN        NaN        NaN     NaN        NaN
# 40     NaN        NaN     NaN        NaN        NaN     NaN        NaN
# 41     NaN        NaN     NaN        NaN        NaN     NaN        NaN
# 42     NaN        NaN     NaN        NaN        NaN     NaN        NaN
# 43     NaN        NaN     NaN        NaN        NaN     NaN        NaN
# 44     NaN        NaN     NaN        NaN        NaN     NaN        NaN
# 45     NaN        NaN     NaN        NaN        NaN     NaN        NaN
# 46     NaN        NaN     NaN        NaN        NaN     NaN        NaN
# 47     NaN        NaN     NaN        NaN        NaN     NaN        NaN
# 48     NaN        NaN     NaN        NaN        NaN     NaN        NaN
# 49     NaN        NaN     NaN        NaN        NaN     NaN        NaN
# 50     NaN        NaN     NaN        NaN        NaN     NaN        NaN
# 51     NaN        NaN     NaN        NaN        NaN     NaN        NaN
# 52     NaN        NaN     NaN        NaN        NaN     NaN        NaN
# 53     NaN        NaN     NaN        NaN        NaN     NaN        NaN
# 54     NaN        NaN     NaN        NaN        NaN     NaN        NaN
# 55     NaN        NaN     NaN        NaN        NaN     NaN        NaN
# 56     NaN        NaN     NaN        NaN        NaN     NaN        NaN
# 57  34.709  24.506001  18.642  35.504002  24.620001  18.948        NaN
# 58  34.709  24.506001  18.642  34.462002  24.909000  17.924        NaN
#
#     c_H2_y  c_H2_z  c_H3_x  c_H3_y  c_H3_z  c_H4_x  c_H4_y  c_H4_z     c_A1_x  \
# 0      NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN        NaN
# 1      NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN        NaN
# 2      NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN        NaN
# 3      NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN        NaN
# 4      NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN        NaN
# 5      NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN        NaN
# 6      NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN        NaN
# 7      NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN        NaN
# 8      NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN        NaN
# 9      NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN        NaN
# 10     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN        NaN
# 11     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN        NaN
# 12     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN        NaN
# 13     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN        NaN
# 14     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN        NaN
# 15     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN        NaN
# 16     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN        NaN
# 17     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN        NaN
# 18     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN        NaN
# 19     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN        NaN
# 20     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN        NaN
# 21     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN        NaN
# 22     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN        NaN
# 23     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN        NaN
# 24     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN        NaN
# 25     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN        NaN
# 26     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN        NaN
# 27  24.909  17.924     NaN     NaN     NaN     NaN     NaN     NaN        NaN
# 28     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN        NaN
# 29     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN  32.025002
# 30     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN  33.995998
# 31     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN  24.540001
# 32     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN  28.049000
# 33     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN  28.336000
# 34     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN        NaN
# 35     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN        NaN
# 36     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN        NaN
# 37     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN        NaN
# 38     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN        NaN
# 39     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN        NaN
# 40     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN        NaN
# 41     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN        NaN
# 42     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN        NaN
# 43     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN        NaN
# 44     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN        NaN
# 45     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN        NaN
# 46     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN        NaN
# 47     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN        NaN
# 48     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN        NaN
# 49     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN        NaN
# 50     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN        NaN
# 51     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN        NaN
# 52     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN        NaN
# 53     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN        NaN
# 54     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN        NaN
# 55     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN        NaN
# 56     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN        NaN
# 57     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN        NaN
# 58     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN        NaN
#
#        c_A1_y     c_A1_z     c_A2_x     c_A2_y     c_A2_z atom_type_label  \
# 0         NaN        NaN        NaN        NaN        NaN           c_aro
# 1         NaN        NaN        NaN        NaN        NaN           c_aro
# 2         NaN        NaN        NaN        NaN        NaN              co
# 3         NaN        NaN        NaN        NaN        NaN           c_aro
# 4         NaN        NaN        NaN        NaN        NaN           c_aro
# 5         NaN        NaN        NaN        NaN        NaN           c_aro
# 6         NaN        NaN        NaN        NaN        NaN         c_alkyl
# 7         NaN        NaN        NaN        NaN        NaN           c_aro
# 8         NaN        NaN        NaN        NaN        NaN         c_alkyl
# 9         NaN        NaN        NaN        NaN        NaN           c_aro
# 10        NaN        NaN        NaN        NaN        NaN              co
# 11        NaN        NaN        NaN        NaN        NaN           c_aro
# 12        NaN        NaN        NaN        NaN        NaN         c_alkyl
# 13        NaN        NaN        NaN        NaN        NaN         c_alkyl
# 14        NaN        NaN        NaN        NaN        NaN           c_aro
# 15        NaN        NaN        NaN        NaN        NaN         c_alkyl
# 16        NaN        NaN        NaN        NaN        NaN         c_alkyl
# 17        NaN        NaN        NaN        NaN        NaN         c_alkyl
# 18        NaN        NaN        NaN        NaN        NaN           c_aro
# 19        NaN        NaN        NaN        NaN        NaN           c_aro
# 20        NaN        NaN        NaN        NaN        NaN           c_aro
# 21        NaN        NaN        NaN        NaN        NaN           c_aro
# 22        NaN        NaN        NaN        NaN        NaN           c_aro
# 23        NaN        NaN        NaN        NaN        NaN           c_aro
# 24        NaN        NaN        NaN        NaN        NaN              co
# 25        NaN        NaN        NaN        NaN        NaN               n
# 26        NaN        NaN        NaN        NaN        NaN               n
# 27        NaN        NaN        NaN        NaN        NaN               n
# 28        NaN        NaN        NaN        NaN        NaN               n
# 29  24.461000  17.629000  31.565001  23.805500  17.958000               n
# 30  23.049000  20.295000  33.776001  23.631001  19.343000               o
# 31  17.396000  20.274000  24.129000  17.025999  19.239000               o
# 32  22.641001  17.554001  28.993000  22.187000  18.011999               o
# 33  26.542999  12.987000  28.088499  25.860001  13.227000               o
# 34        NaN        NaN        NaN        NaN        NaN           h_aro
# 35        NaN        NaN        NaN        NaN        NaN           h_aro
# 36        NaN        NaN        NaN        NaN        NaN           h_aro
# 37        NaN        NaN        NaN        NaN        NaN           h_aro
# 38        NaN        NaN        NaN        NaN        NaN           h_aro
# 39        NaN        NaN        NaN        NaN        NaN           h_aro
# 40        NaN        NaN        NaN        NaN        NaN           h_aro
# 41        NaN        NaN        NaN        NaN        NaN           h_aro
# 42        NaN        NaN        NaN        NaN        NaN         h_alkyl
# 43        NaN        NaN        NaN        NaN        NaN         h_alkyl
# 44        NaN        NaN        NaN        NaN        NaN         h_alkyl
# 45        NaN        NaN        NaN        NaN        NaN         h_alkyl
# 46        NaN        NaN        NaN        NaN        NaN         h_alkyl
# 47        NaN        NaN        NaN        NaN        NaN         h_alkyl
# 48        NaN        NaN        NaN        NaN        NaN         h_alkyl
# 49        NaN        NaN        NaN        NaN        NaN         h_alkyl
# 50        NaN        NaN        NaN        NaN        NaN         h_alkyl
# 51        NaN        NaN        NaN        NaN        NaN         h_alkyl
# 52        NaN        NaN        NaN        NaN        NaN         h_alkyl
# 53        NaN        NaN        NaN        NaN        NaN         h_alkyl
# 54        NaN        NaN        NaN        NaN        NaN         h_alkyl
# 55        NaN        NaN        NaN        NaN        NaN         h_alkyl
# 56        NaN        NaN        NaN        NaN        NaN         h_alkyl
# 57        NaN        NaN        NaN        NaN        NaN           h_pol
# 58        NaN        NaN        NaN        NaN        NaN           h_pol
#
#    seg_chain_resnum lig_resname lig_name
# 0         (A, B, 1)         GG2       C1
# 1         (A, B, 1)         GG2      C10
# 2         (A, B, 1)         GG2      C11
# 3         (A, B, 1)         GG2      C12
# 4         (A, B, 1)         GG2      C13
# 5         (A, B, 1)         GG2      C14
# 6         (A, B, 1)         GG2      C15
# 7         (A, B, 1)         GG2      C16
# 8         (A, B, 1)         GG2      C17
# 9         (A, B, 1)         GG2      C18
# 10        (A, B, 1)         GG2      C19
# 11        (A, B, 1)         GG2       C2
# 12        (A, B, 1)         GG2      C20
# 13        (A, B, 1)         GG2      C21
# 14        (A, B, 1)         GG2      C22
# 15        (A, B, 1)         GG2      C23
# 16        (A, B, 1)         GG2      C24
# 17        (A, B, 1)         GG2      C25
# 18        (A, B, 1)         GG2       C3
# 19        (A, B, 1)         GG2       C4
# 20        (A, B, 1)         GG2      C44
# 21        (A, B, 1)         GG2       C5
# 22        (A, B, 1)         GG2       C6
# 23        (A, B, 1)         GG2       C7
# 24        (A, B, 1)         GG2       C8
# 25        (A, B, 1)         GG2       N1
# 26        (A, B, 1)         GG2       N2
# 27        (A, B, 1)         GG2       N3
# 28        (A, B, 1)         GG2       N5
# 29        (A, B, 1)         GG2       N6
# 30        (A, B, 1)         GG2       O1
# 31        (A, B, 1)         GG2       O2
# 32        (A, B, 1)         GG2       O3
# 33        (A, B, 1)         GG2       O4
# 34        (A, B, 1)         GG2       H2
# 35        (A, B, 1)         GG2       H3
# 36        (A, B, 1)         GG2      H14
# 37        (A, B, 1)         GG2      H18
# 38        (A, B, 1)         GG2      H22
# 39        (A, B, 1)         GG2      H44
# 40        (A, B, 1)         GG2       H5
# 41        (A, B, 1)         GG2       H6
# 42        (A, B, 1)         GG2     H151
# 43        (A, B, 1)         GG2     H152
# 44        (A, B, 1)         GG2     H153
# 45        (A, B, 1)         GG2     H171
# 46        (A, B, 1)         GG2     H172
# 47        (A, B, 1)         GG2     H201
# 48        (A, B, 1)         GG2     H202
# 49        (A, B, 1)         GG2     H211
# 50        (A, B, 1)         GG2     H212
# 51        (A, B, 1)         GG2     H231
# 52        (A, B, 1)         GG2     H232
# 53        (A, B, 1)         GG2     H241
# 54        (A, B, 1)         GG2     H242
# 55        (A, B, 1)         GG2     H251
# 56        (A, B, 1)         GG2     H252
# 57        (A, B, 1)         GG2     HN31
# 58        (A, B, 1)         GG2     HN32

# %% [markdown]
# The conformer can now be superimposed onto CGs of the loaded vdMs.

# %%
# Superpose in series (perhaps best for an HPC job)
s.superpose_ligands_to_CGs(template, frac_non_hb_heavy_buried=0.5, hull_tolerance=0, chunk_size=10000)
# Out:
# Superposing ligands of bb_cco 1 for conformer 1 ...
#      10000 ligands entering clash/burial filters...
#          35 ligands passed clash/burial filters.
#      10000 ligands entering clash/burial filters...
#          42 ligands passed clash/burial filters.
#      10000 ligands entering clash/burial filters...
#          13 ligands passed clash/burial filters.
#      6301 ligands entering clash/burial filters...
#          16 ligands passed clash/burial filters.
# Superposing ligands of bb_cco 2 for conformer 1 ...
#      10000 ligands entering clash/burial filters...
#          3 ligands passed clash/burial filters.
#      10000 ligands entering clash/burial filters...
#          5 ligands passed clash/burial filters.
#      10000 ligands entering clash/burial filters...
#          17 ligands passed clash/burial filters.
#      6301 ligands entering clash/burial filters...
#          9 ligands passed clash/burial filters.
# Superposing ligands of bb_cco 3 for conformer 1 ...
#      10000 ligands entering clash/burial filters...
#          14 ligands passed clash/burial filters.
#      10000 ligands entering clash/burial filters...
#          10 ligands passed clash/burial filters.
#      10000 ligands entering clash/burial filters...
#          33 ligands passed clash/burial filters.
#      6301 ligands entering clash/burial filters...
#          12 ligands passed clash/burial filters.
# Superposing ligands of bb_cco 4 for conformer 1 ...
#      10000 ligands entering clash/burial filters...
#          6 ligands passed clash/burial filters.
#      10000 ligands entering clash/burial filters...
#          8 ligands passed clash/burial filters.
#      10000 ligands entering clash/burial filters...
#          16 ligands passed clash/burial filters.
#      6301 ligands entering clash/burial filters...
#          13 ligands passed clash/burial filters.
# Superposing ligands of bb_cco 5 for conformer 1 ...
#      10000 ligands entering clash/burial filters...
#          29 ligands passed clash/burial filters.
#      10000 ligands entering clash/burial filters...
#          45 ligands passed clash/burial filters.
#      10000 ligands entering clash/burial filters...
#          36 ligands passed clash/burial filters.
#      6301 ligands entering clash/burial filters...
#          13 ligands passed clash/burial filters.
# Superposing ligands of conh2 1 for conformer 1 ...
#      10000 ligands entering clash/burial filters...
#          10 ligands passed clash/burial filters.
#      7611 ligands entering clash/burial filters...
#          11 ligands passed clash/burial filters.
# Loaded  396 ligands

# %%
# # Or superpose in parallel (will execute more quickly if you have the available cpus and memory)
# # Uncomment this cell to load ligands in parallel
# s_ligs = s.__copy__(no_vdms=True, keep_nbrs=True)
# s_ligs.superpose_ligands_to_CGs(template, frac_non_hb_heavy_buried=0.5, hull_tolerance=0,
#                                 chunk_size=10000, run_parallel=True)
# s.set_loaded_ligand_data(s_ligs)

# %% [markdown]
# ### Find CG neighbors of corresponding atoms in each ligand.

# %%
s.find_ligand_cg_neighbors(maxdists=dict(conh2=0.8, bb_cco=0.8))
# Out:
# Finding neighbors of bb_cco 1 ...
# Finding neighbors of bb_cco 2 ...
# Finding neighbors of bb_cco 3 ...
# Finding neighbors of bb_cco 4 ...
# Finding neighbors of bb_cco 5 ...
# Finding neighbors of conh2 1 ...

# %% [markdown]
# ### Define constraints on the ligand/vdM poses for filtering.
# Constraints such as atom burial, ligand/vdM atom contact type, etc, are possible.  See lig_csts.txt for examples.

# %%
path_to_constraint_file = input_dir + 'lig_csts.txt'
s.set_constraints(path_to_constraint_file)

# %% [markdown]
# ### Find poses
# With the neighbors and constraints now defined, proceed by finding the poses that pass the constraint filters.

# %%
s.find_poses(template)
# Out:
# A total of 8 poses were found.

# %% [markdown]
# If many poses are found, their subsequent analysis can be time-consuming. In this case, poses can be prioritized and only the "top" poses submitted for subsequent analysis.

# %%
s.find_poses(template, filter_ligands_by_cluster=True, lig_rmsd_cutoff=1.0, 
             min_ligands_per_cluster=1, top_percent_per_cluster=0.1,
             only_top_percent=0.1, min_poses=50, max_poses=300)
# Out:
# Applying cluster filter to 396 ligands...
# 	  296 ligands remain...
# Applying top-percent filter to 296 ligands...
# 	  50 ligands remain...
# A total of 3 poses were found.

# %% [markdown]
# In the above, ligands will be clustered with a RMSD cutoff of 1.0 Angstroms and filtered by cluster (top 10 percent of ligands in each cluster will be used, or a minimum of 1 ligand per cluster, where "top" refers to designability, see below).  By setting *only_top_percent*=0.1, the top ten percent of remaining ligands will then be used, with a minimum of 50 poses (or less, if 10 percent of the ligands is less than 50), and a maximum of 300 ligands (if 10 percent is greater than 300).  Here, "designability" is a heuristic score, defined as the sum of the log of the number of vdM neighbors to each ligand fragment ("CG ligand coverage number" in ligand.txt).  It prioritizes ligands that have the largest number of vdM neighbors from dispersed sites.
#
# Weights can be supplied to the heuristic ranking function at the level of the "CG ligand coverage number" (the last column in the ligand.txt file).  For example, the following will more heavily weight the vdMs that have CG ligand coverage number 2 (which corresponds to one of the carbonyls of the ligand, in this case) in the ligand.txt file, so that poses will be more highly ranked if they contain a vdM that covers this part of the ligand.

# %%
# # Uncomment this cell to use weights for the heuristic ranking
# vals = [1, 10, 1] # There are 3 different CG ligand coverage numbers in the ligand.txt file.

# # make weights dictionary, where keys are CG ligand coverage number, values are the weights
# weights = {i: vals[i-1] for i in range(1, len(vals) + 1)}

# s.find_poses(template, filter_ligands_by_cluster=True, lig_rmsd_cutoff=1.0, 
#              min_ligands_per_cluster=1, top_percent_per_cluster=0.1,
#              only_top_percent=0.1, min_poses=50, max_poses=300, weight_dict=weights)

# %% [markdown]
# ### Score poses
# Now score the poses that passed the constraint filters.  If using only vdMs that are H-bonding, turn on use_hb_scores.  Otherwise, if using a mixture of non-H-bonding and H-bonding vdMs, it is more fair to score from the same distributions, so set use_hb_scores=False.

# %%
s.score_poses(template, bbdep=True, use_hb_scores=False,
              return_top_scoring_vdMs_only=False)
# Out:
# DEE + brute force
# 0 -1.7145644426345825 [(13, 3, '5TNX_biomol_1_A_A', 'bb_cco', ('A', 'A', 44))]
# DEE + brute force
# 1 -2.7132129669189453 [(4, 1, '3H1N_biomol_1_A_A', 'bb_cco', ('A', 'A', 102))]
# DEE + brute force
# 2 -3.8635698556900024 [(16, 1, '4O4V_biomol_1_A_A', 'bb_cco', ('A', 'A', 102)), (25, 1, '4XWH_biomol_1_A_A', 'bb_cco', ('A', 'A', 95))]

# %% [markdown]
# ### Save to disk
# The Sample object can be saved to disk.  This is convenient to avoid re-loading/pruning vdMs and ligands, but it can take up significant disk space (GBs, depending on how many vdMs/ligands were loaded).

# %%
# # Uncomment this cell to save the full sample object to disk.
# output_dir = input_dir + 'output/'
# s.save(outpath=output_dir, filename='sample_tutorial.pkl')

# %% [markdown]
# The Sample object can also be saved without the loaded vdMs or ligands, which saves significant disk space.  In this way, the poses can be conveniently saved for future computations.

# %%
output_dir = input_dir + 'output/'
s.save(outpath=output_dir, filename='sample_tutorial_poses.pkl', minimal_info_and_poses=True)

# %% [markdown]
# ### Find buried, non-H-bonded, polar atoms
# Get the top scoring poses and compute the number and identities of any buried, "unsatisfied", polar atoms in the vdMs or ligands of the optimum ligand/vdM set.

# %%
poses = s.get_top_poses(top=10)
s.set_buried_unsatisfied(poses, template)

# %% [markdown]
# ### Print the top poses as PDB files.

# %%
output_dir = input_dir + 'output/'
for pose in poses:
    pose.print_opt_pdb(template, outdir=output_dir,
                       include_CG=True, label_vdM_segment_X=True)

# %% [markdown]
# Print the top pose without the CGs:

# %%
poses[0].print_opt_pdb(template, outdir=output_dir,
                       include_CG=False, label_vdM_segment_X=False, tag='_no_CG')

# %% [markdown]
# ### Print score files of top poses.

# %%
for pose in poses:
    pose.print_to_energy_table(outdir=output_dir, filename_tag='_' + gly_pdb_name)

# %% [markdown]
# The top poses can be saved directly to disk by:

# %%
with open(output_dir + 'poses.pkl', 'wb') as outfile:
    pickle.dump(poses, outfile)

# %% [markdown]
# ### Use stored poses as input for another Combs computation.
#
# Saved poses can be loaded into a new Sample object by:

# %%
s_new = combs2.design._sample.Sample() # Create sample, resfile, and load vdMs the usual way

with open(output_dir + 'poses.pkl', 'rb') as infile:
    poses = pickle.load(infile)

s_new.load_poses(poses)

# %% [markdown]
# Ligands from these poses can now be used to lookup neighbors of CGs from vdMs loaded into s_new:

# %%
# #Finding ligand neighbors
# s_new.find_ligand_cg_neighbors(dists=dict(pro=0.8))

# #Add neighboring vdMs to poses
# s_new.add_vdms_to_poses(use_optimum_vdms_only=True, freeze_optimum_vdms=True)

# %% [markdown]
# The above code assumes that vdMs of the "pro" CG were already loaded into the s_new object (not shown).  CG neighbors are computed to the ligands in the loaded poses (the CG-to-ligand atom correspondence file (ligand.txt) must exist and have already been loaded).  Next, the poses are updated with the new neighbors.  A new optimum choice of vdMs will be found using *s.score_poses*, and *use_optimum_vdms_only*=True will use only the previously found optimum vdMs in this new calculation (along with, of course, the newly added "pro" vdMs in this example). The option *freeze_optimum_vdms*=True will ensure the new optimum solution will include each vdM of the previously optimum solution.  So, if a "pro" vdM scored favorably, but were mutually inconsistent with a previously optimum vdM, the new pro vdM would not be substituted for the older vdM (even if its score were better).

# %% [markdown]
# ### vdM Analysis:  Find vdMs in an input PDB file.
#
# For a given input structure, the lookup module **run_lookup_ligand.py** will find the vdMs to a ligand:
#
# ```
# > path_to_lookup=~/Projects/design/Combs2/combs2/programs/run_lookup_ligand.py
# > path_to_lig_txt=../ligand.txt
# > path_to_pdb=1_pose1_no_CG.pdb
# > path_to_db=/Volumes/disk1/Combs/probe_Qbits_2p8/20211005/vdMs/
# > path_to_lig_params=../../HPC_scripts/superpose_ligand/GG2.params
# > outpath=./
# > path_to_probe=~/Projects/design/Combs2/combs2/programs/probe
# > conda activate env_combs #activate combs python environment
# > python $path_to_lookup --lig=$path_to_lig_txt --pdb=$path_to_pdb --db=$path_to_db --o=$outpath --lig_params=$path_to_lig_params --probe=$path_to_probe
# ```

# %% [markdown]
# This will output a csv file that contains the closest-matched vdMs to protein-ligand interactions in the PDB file.

# %%
lig_vdms = pd.read_csv(input_dir + 'output/1_pose1_no_CG_GG2.csv')
lig_vdms.head(10)
# Out:
#   chain_rota  resnum_rota resname_rota chain_CG  resnum_CG CG_type  CG_group  \
# 0          A           95          TYR        L          1  bb_cco         4
# 1          A           95          TYR        L          1  bb_cco         3
# 2          A          102          PHE        L          1  bb_cco         2
# 3          A          102          PHE        L          1  bb_cco         1
#
#    cluster_number  C_score_bb_ind  C_score_hb_bb_ind  C_score_ABPLE  \
# 0              51        1.716003           0.279108       1.402268
# 1              14        2.546934           1.877964       2.713213
# 2             163        0.662221                NaN       1.150357
# 3             284        0.151395                NaN       0.836699
#
#    C_score_hb_ABPLE match_type  rmsd_to_centroid  max_dist_to_centroid
# 0          0.019366      exact          0.366075              0.671119
# 1          2.178850      exact          0.384667              0.618797
# 2               NaN      exact          0.267142              0.537662
# 3               NaN      exact          0.354119              0.579181

# %% [markdown]
# To look up vdMs of protein-protein interactions, **run_lookup.py** can be used:
#
# ```
# > path_to_lookup=~/Projects/design/Combs2/combs2/programs/run_lookup.py
# > path_to_pdb=6w70a.pdb
# > path_to_db=/Volumes/disk1/Combs/probe_Qbits_2p8/20211005/vdMs/
# > outpath=./
# > path_to_probe=~/Projects/design/Combs2/combs2/programs/probe
# > conda activate env_combs #activate combs python environment
# > python $path_to_lookup --pdb=$path_to_pdb --db=$path_to_db --o=$outpath --probe=$path_to_probe
# ```

# %% [markdown]
# ### Load rotamer-filtered vdMs, cluster the CGs, and print top clusters.

# %%
pdb_name = '6w70a.pdb'
pdb = pr.parsePDB(input_dir + pdb_name)
template = combs2.design.template.Template(pdb)
template.set_alpha_hull(pdb, alpha=9)
# Out:
# @> 1905 atoms and 1 coordinate set(s) were parsed in 0.02s.

# %%
path_to_phenix = '/Users/npolizzi/Applications/MolProbity/build/bin/phenix.rotalyze'
template.rotalyze(pdb_path=input_dir + pdb_name,
 path_to_phenix_rotalyze=path_to_phenix)

# %% [markdown]
# Use the *rotamers* option to load rotamer-specific vdMs.

# %%
outpath_resfile = input_dir
segs_chains_resnums = [('','A',14),('','A',6), ('','A',49)]
combs2.design.functions.write_resfile(template,
                                      CGs=['bb_cco', 'conh2'],
                                      outpath=outpath_resfile,
                                      filename='resfile_rotamer',
                                      tag='',
                                      resindices=None,
                                      segs_chains_resnums=segs_chains_resnums,
                                      pikaa_dict=None,
                                      bb_dep=1,
                                      use_enriched_vdMs=True,
                                      CA_burial_distance=None,
                                      exclude_exposed=False,
                                      exclude_intermed=False,
                                      exclude_buried=False,
                                      top_exposed=2,
                                      top_intermed=None,
                                      top_buried=None,
                                      alpha_hull_radius=9,
                                      use_propensities=True,
                                      propensity_threshold=0.9,
                                      use_abple=True,
                                      use_dssp=False,
                                      path_to_pdb_for_dssp=None,
                                      allowed_exposed='KRDENQSTMAGP',
                                      allowed_intermed='NQSTCMAGPVIL',
                                      allowed_buried='AGSTMCPVILHFWY',
                                      hb_only_residues='',
                                      all_contact_residues='HQY',
                                      rotamers=segs_chains_resnums)

# %%
# path to vdM databases
path_to_database='/Volumes/disk1/Combs2/database/20211005/vdMs/'

s = combs2.design._sample.Sample(**dict(path_to_resfile=input_dir + 'resfile_rotamer.txt',
                                        path_to_database=path_to_database))
s.read_resfile()
s.load_vdms(template, filter_by_phi_psi=False, run_parallel=False)
# Out:
# Loading bb_cco
#     Loading GLN
#         Loading residue ('', 'A', 14)
#             Added  46 vdMs of 105 possible before clash filter.
#     Loading TYR
#         Loading residue ('', 'A', 6)
#             Added  39 vdMs of 3713 possible before clash filter.
#     Loading HIS
#         Loading residue ('', 'A', 49)
#             Added  5 vdMs of 449 possible before clash filter.
# Loaded  90 vdMs of bb_cco
# Loading conh2
#     Loading GLN
#         Loading residue ('', 'A', 14)
#             Added  42 vdMs of 57 possible before clash filter.
#     Loading TYR
#         Loading residue ('', 'A', 6)
#             Added  26 vdMs of 2258 possible before clash filter.
#     Loading HIS
#         Loading residue ('', 'A', 49)
#             no vdms due to clashing CGs
# Loaded  68 vdMs of conh2

# %%
path_to_ligand_file = input_dir + 'ligand.txt'
s.set_ligand_vdm_correspondence(path_to_ligand_file)
s.set_cg_neighbors(cg_max_dists=dict(conh2=0.8, bb_cco=0.8))
# Out:
# Setting neighbors...

# %% [markdown]
# Cluster the vdMs and print the top 10 clusters

# %%
output_dir = input_dir + 'output/'

s.cluster_vdms()
for i in range(1, 11):
    s.print_vdm_cluster(cg='conh2', cluster_number=i, outpath=output_dir + 'conh2_clusters/', tag='_clu' + str(i), prefix='')
    s.print_vdm_cluster(cg='bb_cco', cluster_number=i, outpath=output_dir + 'bb_cco_clusters/', tag='_clu' + str(i), prefix='')
